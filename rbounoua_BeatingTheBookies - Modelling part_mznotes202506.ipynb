# %% [markdown]
# # Beating the bookies : a step further

# %% [markdown]
# Here is my second attempt at this exercise. This notebook only contains the modelling part, if you want to streamline the correction and go straight to the point. You will also find the full notebook in the folder, if you need it.
#
# Let's go.

# %%
import pandas as pd
from matplotlib import pyplot as pl
import numpy as np
import seaborn as sns

# %%
Closing_Odds_df = pd.read_csv("/Users/m.zunko/DS/kaggle_beatingBookiesOddsResearchPaper/kaggle_beat-the-bookie-worldwide-football-dataset/closing_odds.csv.gz")
Closing_Odds=Closing_Odds_df.copy()
Closing_Odds
# Out:
#         match_id                   league  match_date     home_team  home_score          away_team  away_score  avg_odds_home_win  avg_odds_draw  avg_odds_away_win  max_odds_home_win  max_odds_draw  max_odds_away_win top_bookie_home_win  top_bookie_draw top_bookie_away_win  n_odds_home_win  n_odds_draw  n_odds_away_win
# 0         170088  England: Premier League  2005-01-01     Liverpool           0            Chelsea           1             2.9944         3.1944             2.2256               3.20           3.25               2.29         Paddy Power      Sportingbet              Expekt                9            9                9
# 1         170089  England: Premier League  2005-01-01        Fulham           3     Crystal Palace           1             1.9456         3.2333             3.6722               2.04           3.30               4.15     Pinnacle Sports      bet-at-home              Expekt                9            9                9
# 2         170090  England: Premier League  2005-01-01   Aston Villa           1          Blackburn           0             1.8522         3.2611             4.0144               2.00           3.40               4.50     Pinnacle Sports      Paddy Power         Sportingbet                9            9                9
# 3         170091  England: Premier League  2005-01-01        Bolton           1          West Brom           1             1.6122         3.4133             5.4722               1.67           3.57               6.27               Coral  Pinnacle Sports     Pinnacle Sports                9            9                9
# 4         170092  England: Premier League  2005-01-01      Charlton           1            Arsenal           3             5.9878         3.4778             1.5567               7.00           3.60               1.62              Expekt      Paddy Power              bet365                9            9                9
# ...          ...                      ...         ...           ...         ...                ...         ...                ...            ...                ...                ...            ...                ...                 ...              ...                 ...              ...          ...              ...
# 479435    876806     World: Club Friendly  2015-06-30    St. Gallen           1   Wacker Innsbruck           2             1.6838         3.8846             3.9813               1.83           4.20               4.33              188BET           bet365           Ladbrokes               24           24               24
# 479436    876807     World: Club Friendly  2015-06-30  SW Harelbeke           1            Waregem           1            13.1165         7.8229             1.1053              19.00           9.00               1.13           BetVictor           bet365            Titanbet               17           17               17
# 479437    876808     World: Club Friendly  2015-06-30       Torhout           0        Club Brugge           5            17.2256        12.6231             1.0288              22.00          15.00               1.05           BetVictor          Jetbull           BetVictor               16           16               16
# 479438    876809     World: Club Friendly  2015-06-30       Tournai           0  Mouscron Peruwelz           3            15.7143        10.2857             1.0614              34.00          12.00               1.10         Sportingbet          Betclic         Paddy Power                7            7                7
# 479439    876812     World: Club Friendly  2015-06-30         Zavrc           0         Istra 1961           0             4.7145         3.9259             1.5650               5.46           4.25               1.70     Pinnacle Sports         888sport           Ladbrokes               22           22               22
#
# [479440 rows x 19 columns]

# %% [markdown]
# I just included here the required steps for data cleaning, adding countries, result and year columns. It's the same code as last time.

# %%
result = 1 * (Closing_Odds['home_score'] > Closing_Odds['away_score']) \
       - 1 * (Closing_Odds['home_score'] < Closing_Odds['away_score'])
        # + 0 * (Closing_Odds['home_score'] == Closing_Odds['away_score'])

#My result column : 1 for HomeWin, 0 for Draw and -1 for AwayWin

    
Closing_Odds.insert(7 ,'result' , result)

Closing_Odds.loc[10773,'home_score']=2
Closing_Odds.loc[10773,'away_score']=0
Closing_Odds.loc[60099,'home_score']=1
Closing_Odds.loc[60099,'away_score']=1
Closing_Odds.loc[97404,'home_score']=0
Closing_Odds.loc[97404,'away_score']=1
Closing_Odds.loc[30817,'home_score']=2
Closing_Odds.loc[30817,'away_score']=0
Closing_Odds.loc[97409,'home_score']=1
Closing_Odds.loc[97409,'away_score']=0

#Update result column
result_col = 1 * (Closing_Odds['home_score'] > Closing_Odds['away_score']) \
       - 1 * (Closing_Odds['home_score'] < Closing_Odds['away_score'])
Closing_Odds['result'] = result_col

Year_col = Closing_Odds['match_date'].apply(lambda date: int(date[:4])) 
Closing_Odds.insert(3,'year',Year_col)

Country_col = Closing_Odds['league'].apply(lambda league: league.split(':')[0]) 
Closing_Odds.insert(1,'country',Country_col)

# %%
Closing_Odds
# Out:
#         match_id  country                   league  match_date  year     home_team  home_score          away_team  away_score  result  avg_odds_home_win  avg_odds_draw  avg_odds_away_win  max_odds_home_win  max_odds_draw  max_odds_away_win top_bookie_home_win  top_bookie_draw top_bookie_away_win  n_odds_home_win  n_odds_draw  n_odds_away_win
# 0         170088  England  England: Premier League  2005-01-01  2005     Liverpool           0            Chelsea           1      -1             2.9944         3.1944             2.2256               3.20           3.25               2.29         Paddy Power      Sportingbet              Expekt                9            9                9
# 1         170089  England  England: Premier League  2005-01-01  2005        Fulham           3     Crystal Palace           1       1             1.9456         3.2333             3.6722               2.04           3.30               4.15     Pinnacle Sports      bet-at-home              Expekt                9            9                9
# 2         170090  England  England: Premier League  2005-01-01  2005   Aston Villa           1          Blackburn           0       1             1.8522         3.2611             4.0144               2.00           3.40               4.50     Pinnacle Sports      Paddy Power         Sportingbet                9            9                9
# 3         170091  England  England: Premier League  2005-01-01  2005        Bolton           1          West Brom           1       0             1.6122         3.4133             5.4722               1.67           3.57               6.27               Coral  Pinnacle Sports     Pinnacle Sports                9            9                9
# 4         170092  England  England: Premier League  2005-01-01  2005      Charlton           1            Arsenal           3      -1             5.9878         3.4778             1.5567               7.00           3.60               1.62              Expekt      Paddy Power              bet365                9            9                9
# ...          ...      ...                      ...         ...   ...           ...         ...                ...         ...     ...                ...            ...                ...                ...            ...                ...                 ...              ...                 ...              ...          ...              ...
# 479435    876806    World     World: Club Friendly  2015-06-30  2015    St. Gallen           1   Wacker Innsbruck           2      -1             1.6838         3.8846             3.9813               1.83           4.20               4.33              188BET           bet365           Ladbrokes               24           24               24
# 479436    876807    World     World: Club Friendly  2015-06-30  2015  SW Harelbeke           1            Waregem           1       0            13.1165         7.8229             1.1053              19.00           9.00               1.13           BetVictor           bet365            Titanbet               17           17               17
# 479437    876808    World     World: Club Friendly  2015-06-30  2015       Torhout           0        Club Brugge           5      -1            17.2256        12.6231             1.0288              22.00          15.00               1.05           BetVictor          Jetbull           BetVictor               16           16               16
# 479438    876809    World     World: Club Friendly  2015-06-30  2015       Tournai           0  Mouscron Peruwelz           3      -1            15.7143        10.2857             1.0614              34.00          12.00               1.10         Sportingbet          Betclic         Paddy Power                7            7                7
# 479439    876812    World     World: Club Friendly  2015-06-30  2015         Zavrc           0         Istra 1961           0       0             4.7145         3.9259             1.5650               5.46           4.25               1.70     Pinnacle Sports         888sport           Ladbrokes               22           22               22
#
# [479440 rows x 22 columns]

# %% [markdown]
# ## II - Introduction of the paper's strategy :

# %%
alpha = 0.05

# %%
Home_condition = ((1/Closing_Odds['avg_odds_home_win']-alpha)*Closing_Odds['max_odds_home_win']-1>0)& (Closing_Odds['n_odds_home_win']>3)

Draw_condition = ((1/Closing_Odds['avg_odds_draw']-alpha)*Closing_Odds['max_odds_draw']-1>0)& (Closing_Odds['n_odds_draw']>3)

Away_condition = ((1/Closing_Odds['avg_odds_away_win']-alpha)*Closing_Odds['max_odds_away_win']-1>0)& (Closing_Odds['n_odds_away_win']>3)

Condition = Home_condition|Draw_condition|Away_condition

# %%
Closing_Odds['condition'] = Condition
Closing_Odds
# Out:
#         match_id  country                   league  match_date  year     home_team  home_score          away_team  away_score  result  avg_odds_home_win  avg_odds_draw  avg_odds_away_win  max_odds_home_win  max_odds_draw  max_odds_away_win top_bookie_home_win  top_bookie_draw top_bookie_away_win  n_odds_home_win  n_odds_draw  n_odds_away_win  condition
# 0         170088  England  England: Premier League  2005-01-01  2005     Liverpool           0            Chelsea           1      -1             2.9944         3.1944             2.2256               3.20           3.25               2.29         Paddy Power      Sportingbet              Expekt                9            9                9      False
# 1         170089  England  England: Premier League  2005-01-01  2005        Fulham           3     Crystal Palace           1       1             1.9456         3.2333             3.6722               2.04           3.30               4.15     Pinnacle Sports      bet-at-home              Expekt                9            9                9      False
# 2         170090  England  England: Premier League  2005-01-01  2005   Aston Villa           1          Blackburn           0       1             1.8522         3.2611             4.0144               2.00           3.40               4.50     Pinnacle Sports      Paddy Power         Sportingbet                9            9                9      False
# 3         170091  England  England: Premier League  2005-01-01  2005        Bolton           1          West Brom           1       0             1.6122         3.4133             5.4722               1.67           3.57               6.27               Coral  Pinnacle Sports     Pinnacle Sports                9            9                9      False
# 4         170092  England  England: Premier League  2005-01-01  2005      Charlton           1            Arsenal           3      -1             5.9878         3.4778             1.5567               7.00           3.60               1.62              Expekt      Paddy Power              bet365                9            9                9      False
# ...          ...      ...                      ...         ...   ...           ...         ...                ...         ...     ...                ...            ...                ...                ...            ...                ...                 ...              ...                 ...              ...          ...              ...        ...
# 479435    876806    World     World: Club Friendly  2015-06-30  2015    St. Gallen           1   Wacker Innsbruck           2      -1             1.6838         3.8846             3.9813               1.83           4.20               4.33              188BET           bet365           Ladbrokes               24           24               24      False
# 479436    876807    World     World: Club Friendly  2015-06-30  2015  SW Harelbeke           1            Waregem           1       0            13.1165         7.8229             1.1053              19.00           9.00               1.13           BetVictor           bet365            Titanbet               17           17               17      False
# 479437    876808    World     World: Club Friendly  2015-06-30  2015       Torhout           0        Club Brugge           5      -1            17.2256        12.6231             1.0288              22.00          15.00               1.05           BetVictor          Jetbull           BetVictor               16           16               16      False
# 479438    876809    World     World: Club Friendly  2015-06-30  2015       Tournai           0  Mouscron Peruwelz           3      -1            15.7143        10.2857             1.0614              34.00          12.00               1.10         Sportingbet          Betclic         Paddy Power                7            7                7      False
# 479439    876812    World     World: Club Friendly  2015-06-30  2015         Zavrc           0         Istra 1961           0       0             4.7145         3.9259             1.5650               5.46           4.25               1.70     Pinnacle Sports         888sport           Ladbrokes               22           22               22       True
#
# [479440 rows x 23 columns]

# %%
Closing_Odds.loc[Closing_Odds.match_id==237986, :]
# Out:
#        match_id country                         league  match_date  year   home_team  home_score away_team  away_score  result  avg_odds_home_win  avg_odds_draw  avg_odds_away_win  max_odds_home_win  max_odds_draw  max_odds_away_win top_bookie_home_win top_bookie_draw top_bookie_away_win  n_odds_home_win  n_odds_draw  n_odds_away_win  condition
# 31226    237986   World  World: Friendly International  2006-06-03  2006  Luxembourg           0  Portugal           3      -1               37.9          8.875             1.0275               67.0           10.0               1.05               Coral     bet-at-home             DOXXbet                8            8                8      False

# %%
Home_condition[31225:31228]
# Out:
# 31225    False
# 31226    False
# 31227    False
# dtype: bool

# %%
# mznote: test Y definition and check proportion
print(Condition.sum())
print(Condition.sum()/len(Condition))
# Out:
# 56435
# 0.11771024528616719

# %%
# mznote: OK

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# Our strategy now consists in finding ways to predict this odd-related condition for new games, without access to odds data.
#
# The first step will be to understand what makes a game likely to fulfill this condition. To do that, we will test our hypothesis against the data we have, and detail our thought process and conclusions.
#
# Then we can add new features to the dataset, hoping it leads to the best predictive model in the end.

# %% [markdown]
# ### #1 : Number of odds available

# %% [markdown]
# As we saw in the EDA part, the competition impact might be our biggest ally in this one. We want to find games that have the most odds to bet on, because it forces bookmakers to differenciate themselves and increases our chance of finding advantageous games to bet on.

# %% [markdown]
# For reference, here are the number of odds distribution, with the associated advantageous games in orange. We have to find a way to estimate this feature in our model (because we can't access it right away as it is unavailable for our purposes).

# %%
X = range(1,len(Closing_Odds['n_odds_draw'].unique())+1)
Y = Closing_Odds.groupby('n_odds_draw')['condition'].describe()["count"]
Y2 = [0,0,0]+list(Closing_Odds[Closing_Odds['condition']==True].groupby('n_odds_draw')['condition'].describe()["count"])

fig = pl.figure()
ax = fig.add_subplot(111)
ax.bar(x=X, height=Y, width=.7, align='center')
ax.bar(x=X, height=Y2, width=.7, align='center')


pl.tight_layout()
pl.show()

# %% [markdown]
# Let's try to estimate the "n_odds_draw" feature, by computing a rolling average sorting games by leagues.
#
# In practice, each game would have a new feature that will entail the average odds available for draw in the last 5 games played in the same league. That way we can approximate the number of odds available to bet on draw for this game, which will then help us deterine the "condition" label with our model.

# %%
def get_n_odds_est(df):
    # Sort the DataFrame by league and match_id to ensure chronological order
    df = df.sort_values(by=['league', 'match_id'])
    
    # Group by league and compute the rolling average for 'n_odds_draw'
    rolling_means = (
        df.groupby('league')['n_odds_draw']
        .apply(lambda x: x.rolling(window=5, min_periods=1).mean())
    )
    
    df['n_odds_est'] = rolling_means.reset_index(drop=True)
    
    return df

# Apply the function to the dataframe
Closing_Odds = get_n_odds_est(Closing_Odds)
Closing_Odds.sort_values(by='match_id').reset_index(drop=True).head(10)
# Out:
#    match_id  country                   league  match_date  year        home_team  home_score          away_team  away_score  result  avg_odds_home_win  avg_odds_draw  avg_odds_away_win  max_odds_home_win  max_odds_draw  max_odds_away_win top_bookie_home_win  top_bookie_draw top_bookie_away_win  n_odds_home_win  n_odds_draw  n_odds_away_win  condition  n_odds_est
# 0    170088  England  England: Premier League  2005-01-01  2005        Liverpool           0            Chelsea           1      -1             2.9944         3.1944             2.2256               3.20           3.25               2.29         Paddy Power      Sportingbet              Expekt                9            9                9      False        19.0
# 1    170089  England  England: Premier League  2005-01-01  2005           Fulham           3     Crystal Palace           1       1             1.9456         3.2333             3.6722               2.04           3.30               4.15     Pinnacle Sports      bet-at-home              Expekt                9            9                9      False        14.0
# 2    170090  England  England: Premier League  2005-01-01  2005      Aston Villa           1          Blackburn           0       1             1.8522         3.2611             4.0144               2.00           3.40               4.50     Pinnacle Sports      Paddy Power         Sportingbet                9            9                9      False        16.0
# 3    170091  England  England: Premier League  2005-01-01  2005           Bolton           1          West Brom           1       0             1.6122         3.4133             5.4722               1.67           3.57               6.27               Coral  Pinnacle Sports     Pinnacle Sports                9            9                9      False        17.0
# 4    170092  England  England: Premier League  2005-01-01  2005         Charlton           1            Arsenal           3      -1             5.9878         3.4778             1.5567               7.00           3.60               1.62              Expekt      Paddy Power              bet365                9            9                9      False        17.6
# 5    170093  England  England: Premier League  2005-01-01  2005  Manchester City           2        Southampton           1       1             1.7000         3.3667             4.7344               1.73           3.50               5.00              bet365           Expekt              bet365                9            9                9      False        17.8
# 6    170094  England  England: Premier League  2005-01-01  2005    Newcastle Utd           2         Birmingham           1       1             1.8622         3.2500             3.9622               1.91           3.40               4.33              bet365      Sportingbet              bet365                9            9                9      False        20.0
# 7    170095  England  England: Premier League  2005-01-01  2005       Portsmouth           1            Norwich           1       0             1.6344         3.3933             5.2633               1.70           3.54               6.14        William Hill  Pinnacle Sports     Pinnacle Sports                9            9                9      False        20.0
# 8    170096  England  England: Premier League  2005-01-01  2005        Tottenham           5            Everton           2       1             2.2156         3.1722             3.0444               2.29           3.20               3.35              Expekt           bet365     Pinnacle Sports                9            9                9      False        19.8
# 9    170097  England  England: Premier League  2005-01-01  2005    Middlesbrough           0  Manchester United           2      -1             3.3611         3.2222             2.0489               3.75           3.25               2.10              bet365           Expekt               Coral                9            9                9      False        19.6

# %%
Closing_Odds.n_odds_est.isnull().sum()
# Out:
# 0

# %%
# mznote: n_odds_draw has only nines, while n_odds_est shows 19, 14, 16... ?!?

# %%
Closing_Odds.loc[:, ["league", "match_id", "match_date", "n_odds_draw", "n_odds_est"]].sort_values(by=['league', 'match_id']).head()
# Out:
#                               league  match_id  match_date  n_odds_draw  n_odds_est
# 71890  Africa: Africa Cup of Nations    316345  2008-01-29           19        21.0
# 71891  Africa: Africa Cup of Nations    316346  2008-01-29            9        21.2
# 71947  Africa: Africa Cup of Nations    316426  2008-01-30           20        19.8
# 71948  Africa: Africa Cup of Nations    316427  2008-01-30           20        20.2
# 71988  Africa: Africa Cup of Nations    316479  2008-01-31           20        23.6

# %%
Closing_Odds.loc[Closing_Odds.league=="England: Premier League", ["league", "match_id", "match_date", "n_odds_draw", "n_odds_est"]].sort_values(by=['league', 'match_id']).head()
# Out:
#                     league  match_id  match_date  n_odds_draw  n_odds_est
# 0  England: Premier League    170088  2005-01-01            9        19.0
# 1  England: Premier League    170089  2005-01-01            9        14.0
# 2  England: Premier League    170090  2005-01-01            9        16.0
# 3  England: Premier League    170091  2005-01-01            9        17.0
# 4  England: Premier League    170092  2005-01-01            9        17.6

# %%
epl = Closing_Odds.loc[Closing_Odds.league=="England: Premier League", :].sort_values(by=['league', 'match_id'])
rolling_means = (
        epl.groupby('league')['n_odds_draw']
        .apply(lambda x: x.rolling(window=5, min_periods=1).mean())
    )

# %%
rolling_means[:10]
# Out:
# league
# England: Premier League  0    9.0
#                          1    9.0
#                          2    9.0
#                          3    9.0
#                          4    9.0
#                          5    9.0
#                          6    9.0
#                          7    9.0
#                          8    9.0
#                          9    9.0
# Name: n_odds_draw, dtype: float64

# %%
epl['n_odds_est'] = rolling_means.reset_index(drop=True)
# epl['n_odds_est2'] = rolling_means
epl.loc[:, 'n_odds_est3'] = rolling_means.values
epl.head(10)
# Out:
#    match_id  country                   league  match_date  year        home_team  home_score          away_team  away_score  result  avg_odds_home_win  avg_odds_draw  avg_odds_away_win  max_odds_home_win  max_odds_draw  max_odds_away_win top_bookie_home_win  top_bookie_draw top_bookie_away_win  n_odds_home_win  n_odds_draw  n_odds_away_win  condition  n_odds_est  n_odds_est3
# 0    170088  England  England: Premier League  2005-01-01  2005        Liverpool           0            Chelsea           1      -1             2.9944         3.1944             2.2256               3.20           3.25               2.29         Paddy Power      Sportingbet              Expekt                9            9                9      False         9.0          9.0
# 1    170089  England  England: Premier League  2005-01-01  2005           Fulham           3     Crystal Palace           1       1             1.9456         3.2333             3.6722               2.04           3.30               4.15     Pinnacle Sports      bet-at-home              Expekt                9            9                9      False         9.0          9.0
# 2    170090  England  England: Premier League  2005-01-01  2005      Aston Villa           1          Blackburn           0       1             1.8522         3.2611             4.0144               2.00           3.40               4.50     Pinnacle Sports      Paddy Power         Sportingbet                9            9                9      False         9.0          9.0
# 3    170091  England  England: Premier League  2005-01-01  2005           Bolton           1          West Brom           1       0             1.6122         3.4133             5.4722               1.67           3.57               6.27               Coral  Pinnacle Sports     Pinnacle Sports                9            9                9      False         9.0          9.0
# 4    170092  England  England: Premier League  2005-01-01  2005         Charlton           1            Arsenal           3      -1             5.9878         3.4778             1.5567               7.00           3.60               1.62              Expekt      Paddy Power              bet365                9            9                9      False         9.0          9.0
# 5    170093  England  England: Premier League  2005-01-01  2005  Manchester City           2        Southampton           1       1             1.7000         3.3667             4.7344               1.73           3.50               5.00              bet365           Expekt              bet365                9            9                9      False         9.0          9.0
# 6    170094  England  England: Premier League  2005-01-01  2005    Newcastle Utd           2         Birmingham           1       1             1.8622         3.2500             3.9622               1.91           3.40               4.33              bet365      Sportingbet              bet365                9            9                9      False         9.0          9.0
# 7    170095  England  England: Premier League  2005-01-01  2005       Portsmouth           1            Norwich           1       0             1.6344         3.3933             5.2633               1.70           3.54               6.14        William Hill  Pinnacle Sports     Pinnacle Sports                9            9                9      False         9.0          9.0
# 8    170096  England  England: Premier League  2005-01-01  2005        Tottenham           5            Everton           2       1             2.2156         3.1722             3.0444               2.29           3.20               3.35              Expekt           bet365     Pinnacle Sports                9            9                9      False         9.0          9.0
# 9    170097  England  England: Premier League  2005-01-01  2005    Middlesbrough           0  Manchester United           2      -1             3.3611         3.2222             2.0489               3.75           3.25               2.10              bet365           Expekt               Coral                9            9                9      False         9.0          9.0

# %%
england = Closing_Odds.loc[Closing_Odds.country=="England", :].sort_values(by=['league', 'match_id'])
rolling_means = (
        epl.groupby('league')['n_odds_draw']
        .apply(lambda x: x.rolling(window=5, min_periods=1).mean())
    )
rolling_means[:10]
# Out:
# league
# England: Premier League  0    9.0
#                          1    9.0
#                          2    9.0
#                          3    9.0
#                          4    9.0
#                          5    9.0
#                          6    9.0
#                          7    9.0
#                          8    9.0
#                          9    9.0
# Name: n_odds_draw, dtype: float64

# %%
rolling_means = (
        Closing_Odds.sort_values(by=['league', 'match_id']).groupby('league')['n_odds_draw']
        .apply(lambda x: x.rolling(window=5, min_periods=1).mean())
    )
rolling_means[:10]
# Out:
# league
# Africa: Africa Cup of Nations  71890    19.0
#                                71891    14.0
#                                71947    16.0
#                                71948    17.0
#                                71988    17.6
#                                71989    17.8
#                                72195    20.0
#                                72196    20.0
#                                72311    19.8
#                                72312    19.6
# Name: n_odds_draw, dtype: float64

# %%
rolling_means.reset_index(drop=True).head(10)
# Out:
# 0    19.0
# 1    14.0
# 2    16.0
# 3    17.0
# 4    17.6
# 5    17.8
# 6    20.0
# 7    20.0
# 8    19.8
# 9    19.6
# Name: n_odds_draw, dtype: float64

# %%
def get_n_odds_est_fixed(df):
    df = df.sort_values(by=['league', 'match_id'])
    rolling_means = (
        df.groupby('league')['n_odds_draw']
        .apply(lambda x: x.rolling(window=5, min_periods=1).mean())
    )
    
    df.loc[:, 'n_odds_est_fixed'] = rolling_means.values
    
    return df
#

# %%
Closing_Odds = get_n_odds_est_fixed(Closing_Odds)
Closing_Odds = Closing_Odds.sort_values(by='match_id').reset_index(drop=True)
Closing_Odds.loc[:, "n_odds_est_fixed_with_lag"] = Closing_Odds.groupby('league')['n_odds_draw'].transform(lambda x: x.rolling(5, 1, closed="left").mean())
Closing_Odds.sort_values(by='match_id').reset_index(drop=True).head(10)
# Out:
#    match_id  country                   league  match_date  year        home_team  home_score          away_team  away_score  result  avg_odds_home_win  avg_odds_draw  avg_odds_away_win  max_odds_home_win  max_odds_draw  max_odds_away_win top_bookie_home_win  top_bookie_draw top_bookie_away_win  n_odds_home_win  n_odds_draw  n_odds_away_win  condition  n_odds_est  n_odds_est_fixed  n_odds_est_fixed_with_lag
# 0    170088  England  England: Premier League  2005-01-01  2005        Liverpool           0            Chelsea           1      -1             2.9944         3.1944             2.2256               3.20           3.25               2.29         Paddy Power      Sportingbet              Expekt                9            9                9      False        19.0               9.0                        NaN
# 1    170089  England  England: Premier League  2005-01-01  2005           Fulham           3     Crystal Palace           1       1             1.9456         3.2333             3.6722               2.04           3.30               4.15     Pinnacle Sports      bet-at-home              Expekt                9            9                9      False        14.0               9.0                        9.0
# 2    170090  England  England: Premier League  2005-01-01  2005      Aston Villa           1          Blackburn           0       1             1.8522         3.2611             4.0144               2.00           3.40               4.50     Pinnacle Sports      Paddy Power         Sportingbet                9            9                9      False        16.0               9.0                        9.0
# 3    170091  England  England: Premier League  2005-01-01  2005           Bolton           1          West Brom           1       0             1.6122         3.4133             5.4722               1.67           3.57               6.27               Coral  Pinnacle Sports     Pinnacle Sports                9            9                9      False        17.0               9.0                        9.0
# 4    170092  England  England: Premier League  2005-01-01  2005         Charlton           1            Arsenal           3      -1             5.9878         3.4778             1.5567               7.00           3.60               1.62              Expekt      Paddy Power              bet365                9            9                9      False        17.6               9.0                        9.0
# 5    170093  England  England: Premier League  2005-01-01  2005  Manchester City           2        Southampton           1       1             1.7000         3.3667             4.7344               1.73           3.50               5.00              bet365           Expekt              bet365                9            9                9      False        17.8               9.0                        9.0
# 6    170094  England  England: Premier League  2005-01-01  2005    Newcastle Utd           2         Birmingham           1       1             1.8622         3.2500             3.9622               1.91           3.40               4.33              bet365      Sportingbet              bet365                9            9                9      False        20.0               9.0                        9.0
# 7    170095  England  England: Premier League  2005-01-01  2005       Portsmouth           1            Norwich           1       0             1.6344         3.3933             5.2633               1.70           3.54               6.14        William Hill  Pinnacle Sports     Pinnacle Sports                9            9                9      False        20.0               9.0                        9.0
# 8    170096  England  England: Premier League  2005-01-01  2005        Tottenham           5            Everton           2       1             2.2156         3.1722             3.0444               2.29           3.20               3.35              Expekt           bet365     Pinnacle Sports                9            9                9      False        19.8               9.0                        9.0
# 9    170097  England  England: Premier League  2005-01-01  2005    Middlesbrough           0  Manchester United           2      -1             3.3611         3.2222             2.0489               3.75           3.25               2.10              bet365           Expekt               Coral                9            9                9      False        19.6               9.0                        9.0

# %%
# mznote:
# Remi's code has an error: England matches (get first when sorting by match_id) get averages of African matches (get first when sorting by league & match_id)

# %% [markdown]
# How accurate is this estimator ? Can we actually approximate the number of odds available for a game based on the numbe rof odds available for the last 5 league's games ?

# %%
actual = sorted(Closing_Odds["n_odds_draw"])
predicted = sorted(Closing_Odds["n_odds_est"])

pl.figure(figsize=(8, 6))
pl.scatter(actual, predicted, alpha=0.7, label='Predicted vs Actual')

# Ideal line (y = x)
min_val = min(min(actual), min(predicted))
max_val = max(max(actual), max(predicted))
pl.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Ideal (y=x)')
pl.show()

# %% [markdown]
# This graph show us that the estimations (blue ticks) are in the very proximity of the red dotted line (theory of what we should have gotten). Our estimator slightly overestimates low available odds and slightly understimates high available odds.

# %%
actual = sorted(Closing_Odds["n_odds_draw"])
predicted = sorted(Closing_Odds["n_odds_est_fixed"])

pl.figure(figsize=(8, 6))
pl.scatter(actual, predicted, alpha=0.7, label='Predicted vs Actual')

# Ideal line (y = x)
min_val = min(min(actual), min(predicted))
max_val = max(max(actual), max(predicted))
pl.plot([min_val, max_val], [min_val, max_val], color='red', linestyle='--', label='Ideal (y=x)')
pl.show()

# %%
# mznote: build a model instead. Interpret it!
actual = Closing_Odds.loc[~Closing_Odds.n_odds_est_fixed_with_lag.isnull(), "n_odds_draw"]
predicted = Closing_Odds.loc[~Closing_Odds.n_odds_est_fixed_with_lag.isnull(), "n_odds_est_fixed_with_lag"]

import statsmodels.api as sm
mod = sm.OLS(actual, sm.add_constant(predicted))
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            n_odds_draw   R-squared:                       0.895
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                 4.063e+06
# Date:                Wed, 18 Jun 2025   Prob (F-statistic):               0.00
# Time:                        15:09:19   Log-Likelihood:            -1.1826e+06
# No. Observations:              478622   AIC:                         2.365e+06
# Df Residuals:                  478620   BIC:                         2.365e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# =============================================================================================
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------
# const                         0.4396      0.009     49.033      0.000       0.422       0.457
# n_odds_est_fixed_with_lag     0.9760      0.000   2015.635      0.000       0.975       0.977
# ==============================================================================
# Omnibus:                   172665.907   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          2912841.981
# Skew:                          -1.293   Prob(JB):                         0.00
# Kurtosis:                      14.806   Cond. No.                         40.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### #2 : Month of the year

# %% [markdown]
# Here is a theory : What if games played at the beginning of the season (aka end of the year) have more variance because teams have spent the last few months not playing. Bookmakers have to guess teams' form, they don't have access to recent games. Maybe it's a good way to find variance in odds distribution, let's see

# %%
Closing_Odds["month"] = Closing_Odds["match_date"].apply(lambda date: int(date[5:7]))

# %%
Closing_Odds.groupby("month").match_date.min()
# Out:
# month
# 1     2005-01-01
# 2     2005-02-01
# 3     2005-03-01
# 4     2005-04-01
# 5     2005-05-01
# 6     2005-06-01
# 7     2005-07-01
# 8     2005-08-01
# 9     2005-09-01
# 10    2005-10-01
# 11    2005-11-01
# 12    2005-12-01
# Name: match_date, dtype: object

# %%
X = range(1, 13)
Y = Closing_Odds.groupby('month')['condition'].describe()["count"]
Y2 = Closing_Odds[Closing_Odds['condition']==True].groupby('month')['condition'].describe()["count"]

ratios = (Y2 / Y) * 100

fig, axes = pl.subplots(1, 2, figsize=(12, 6))

axes[0].bar(x=X, height=Y, width=0.7, align='center')
axes[0].bar(x=X, height=Y2, width=0.7, align='center')
axes[0].set_title("Games per month")


axes[1].bar(x=X, height=ratios, width=0.7, color='grey', align='center')
axes[1].set_title("% of 'good' games per month")


pl.tight_layout()
pl.show()

# %% [markdown]
# This graph represents the games by months of the year, from Jan to Dec. On the left, the blue bar is the total games played, and the orange bars are the ones with Condition equal to True. On the right, we have the ratio of good games to bet on / all games divided per months.

# %% [markdown]
# From a graph standpoint, the conclusion is hard to see. Games in July and August are rare, but have a higher % of true condition. It's hard to act on that information, because the lack of volume of games is detrimental to our use case, we shouldn't draw too much from this.

# %% [markdown]
# ### #3: Condition estimator based on leagues

# %% [markdown]
# We want to predict our condition. Why wouldn't we make a feature trying to capture a league's chance of having a game fulfilling that condition ?
#
# For each game, we calculate the ratio of past conditions for each game within the same league.

# %% [markdown]
# ##### Example :
#
# At the start of the 2006 Premier League season, 180 games have been played :

# %%
Closing_Odds[
    (Closing_Odds['league']=="England: Premier League")&
    (Closing_Odds['year']<=2005)&
    (Closing_Odds['month']<=7)]
# Out:
#       match_id  country                   league  match_date  year          home_team  home_score          away_team  away_score  result  avg_odds_home_win  avg_odds_draw  avg_odds_away_win  max_odds_home_win  max_odds_draw  max_odds_away_win top_bookie_home_win  top_bookie_draw top_bookie_away_win  n_odds_home_win  n_odds_draw  n_odds_away_win  condition  n_odds_est  n_odds_est_fixed  n_odds_est_fixed_with_lag  month
# 0       170088  England  England: Premier League  2005-01-01  2005          Liverpool           0            Chelsea           1      -1             2.9944         3.1944             2.2256               3.20           3.25               2.29         Paddy Power      Sportingbet              Expekt                9            9                9      False   19.000000               9.0                        NaN      1
# 1       170089  England  England: Premier League  2005-01-01  2005             Fulham           3     Crystal Palace           1       1             1.9456         3.2333             3.6722               2.04           3.30               4.15     Pinnacle Sports      bet-at-home              Expekt                9            9                9      False   14.000000               9.0                        9.0      1
# 2       170090  England  England: Premier League  2005-01-01  2005        Aston Villa           1          Blackburn           0       1             1.8522         3.2611             4.0144               2.00           3.40               4.50     Pinnacle Sports      Paddy Power         Sportingbet                9            9                9      False   16.000000               9.0                        9.0      1
# 3       170091  England  England: Premier League  2005-01-01  2005             Bolton           1          West Brom           1       0             1.6122         3.4133             5.4722               1.67           3.57               6.27               Coral  Pinnacle Sports     Pinnacle Sports                9            9                9      False   17.000000               9.0                        9.0      1
# 4       170092  England  England: Premier League  2005-01-01  2005           Charlton           1            Arsenal           3      -1             5.9878         3.4778             1.5567               7.00           3.60               1.62              Expekt      Paddy Power              bet365                9            9                9      False   17.600000               9.0                        9.0      1
# 5       170093  England  England: Premier League  2005-01-01  2005    Manchester City           2        Southampton           1       1             1.7000         3.3667             4.7344               1.73           3.50               5.00              bet365           Expekt              bet365                9            9                9      False   17.800000               9.0                        9.0      1
# 6       170094  England  England: Premier League  2005-01-01  2005      Newcastle Utd           2         Birmingham           1       1             1.8622         3.2500             3.9622               1.91           3.40               4.33              bet365      Sportingbet              bet365                9            9                9      False   20.000000               9.0                        9.0      1
# 7       170095  England  England: Premier League  2005-01-01  2005         Portsmouth           1            Norwich           1       0             1.6344         3.3933             5.2633               1.70           3.54               6.14        William Hill  Pinnacle Sports     Pinnacle Sports                9            9                9      False   20.000000               9.0                        9.0      1
# 8       170096  England  England: Premier League  2005-01-01  2005          Tottenham           5            Everton           2       1             2.2156         3.1722             3.0444               2.29           3.20               3.35              Expekt           bet365     Pinnacle Sports                9            9                9      False   19.800000               9.0                        9.0      1
# 9       170097  England  England: Premier League  2005-01-01  2005      Middlesbrough           0  Manchester United           2      -1             3.3611         3.2222             2.0489               3.75           3.25               2.10              bet365           Expekt               Coral                9            9                9      False   19.600000               9.0                        9.0      1
# 75      170226  England  England: Premier League  2005-01-03  2005            Norwich           1          Liverpool           2      -1             5.3750         3.4250             1.6288               6.00           3.50               1.67              Expekt            Coral              bet365                8            8                8      False   21.200000               8.8                        9.0      1
# 76      170227  England  England: Premier League  2005-01-03  2005          Blackburn           1           Charlton           0       1             2.2567         3.2078             2.9267               2.29           3.25               3.22              bet365           bet365     Pinnacle Sports                9            9                9      False   21.200000               8.8                        8.8      1
# 77      170228  England  England: Premier League  2005-01-03  2005     Crystal Palace           2        Aston Villa           0       1             2.6478         3.1889             2.4611               2.85           3.25               2.60              Expekt        Ladbrokes               Coral                9            9                9      False   21.200000               8.8                        8.8      1
# 78      170229  England  England: Premier League  2005-01-03  2005          West Brom           0      Newcastle Utd           0       0             4.0089         3.2778             1.8389               4.50           3.40               1.91         Paddy Power            Coral         Sportingbet                9            9                9      False   20.800000               8.8                        8.8      1
# 136     170329  England  England: Premier League  2005-01-04  2005            Arsenal           1    Manchester City           1       0             1.2733         4.8144             9.5489               1.30           5.00               9.99              Expekt           bet365         bet-at-home                9            9                9      False   26.000000               8.8                        8.8      1
# 137     170330  England  England: Premier League  2005-01-04  2005         Birmingham           1             Bolton           2      -1             1.8233         3.2722             4.1144               1.99           3.40               4.50     Pinnacle Sports            Coral              bet365                9            9                9      False   24.800000               9.0                        8.8      1
# 138     170331  England  England: Premier League  2005-01-04  2005            Chelsea           2      Middlesbrough           0       1             1.3367         4.2989             8.7211               1.36           5.00               9.99              bet365           Expekt              Expekt                9            9                9      False   24.600000               9.0                        9.0      1
# 139     170332  England  England: Premier League  2005-01-04  2005            Everton           2         Portsmouth           1       1             1.7356         3.2889             4.6056               1.83           3.40               5.00     Pinnacle Sports      Sportingbet              bet365                9            9                9      False   23.800000               9.0                        9.0      1
# 140     170333  England  England: Premier League  2005-01-04  2005  Manchester United           0          Tottenham           0       0             1.4044         4.0056             7.3333               1.44           4.30               8.00              bet365           Expekt              Expekt                9            9                9      False   22.800000               9.0                        9.0      1
# 142     170348  England  England: Premier League  2005-01-05  2005        Southampton           3             Fulham           3       0             2.3244         3.2089             2.8100               2.40           3.30               3.00              Expekt     William Hill              bet365                9            9                9      False   19.000000               9.0                        9.0      1
# 405     171038  England  England: Premier League  2005-01-15  2005          Liverpool           0  Manchester United           1      -1             2.6170         3.0950             2.5860               2.88           3.20               2.90         Paddy Power           bet365     Pinnacle Sports               10           10               10      False   27.800000               9.2                        9.0      1
# 406     171039  England  England: Premier League  2005-01-15  2005        Aston Villa           3            Norwich           0       1             1.6610         3.3550             5.1570               1.72           3.46               6.04              bet365  Pinnacle Sports     Pinnacle Sports               10           10               10      False   28.000000               9.4                        9.2      1
# 407     171040  England  England: Premier League  2005-01-15  2005           Charlton           3         Birmingham           1       1             2.0630         3.1580             3.4090               2.20           3.25               3.60              bet365        BetVictor           BetVictor               10           10               10      False   27.600000               9.6                        9.4      1
# 408     171041  England  England: Premier League  2005-01-15  2005    Manchester City           3     Crystal Palace           1       1             1.6360         3.4180             5.1830               1.67           3.60               6.00               Coral           bet365              Expekt               10           10               10      False   27.400000               9.8                        9.6      1
# 409     171042  England  England: Premier League  2005-01-15  2005      Newcastle Utd           2        Southampton           1       1             1.5370         3.5450             6.0950               1.57           3.85               7.00              bet365  Pinnacle Sports              Expekt               10           10               10      False   27.600000              10.0                        9.8      1
# 410     171043  England  England: Premier League  2005-01-15  2005         Portsmouth           0          Blackburn           1      -1             2.0310         3.1950             3.4690               2.20           3.25               3.75              bet365      bet-at-home           BetVictor               10           10               10      False   27.800000              10.0                       10.0      1
# 411     171044  England  England: Premier League  2005-01-15  2005          Tottenham           0            Chelsea           2      -1             4.2370         3.2650             1.8120               4.65           3.40               1.87              Expekt      Sportingbet     Pinnacle Sports               10           10               10      False   28.000000              10.0                       10.0      1
# 412     171045  England  England: Premier League  2005-01-15  2005             Bolton           1            Arsenal           0       1             5.7650         3.5050             1.5700               6.00           3.60               1.65              bet365           bet365              Expekt               10           10               10      False   28.400000              10.0                       10.0      1
# 502     171217  England  England: Premier League  2005-01-16  2005      Middlesbrough           1            Everton           1       0             2.0130         3.1900             3.4850               2.10           3.25               3.80        William Hill        BetVictor              Expekt               10           10               10      False   20.000000              10.0                       10.0      1
# 503     171218  England  England: Premier League  2005-01-16  2005             Fulham           1          West Brom           0       1             1.7530         3.2170             4.7090               1.80           3.35               5.00              bet365      bet-at-home              bet365               10           10               10      False   20.400000              10.0                       10.0      1
# 638     171686  England  England: Premier League  2005-01-22  2005        Southampton           2          Liverpool           0       1             4.3500         3.2750             1.7900               4.80           3.40               1.83              Expekt        BetVictor              bet365               10           10               10      False    2.200000              10.0                       10.0      1
# 639     171687  England  England: Premier League  2005-01-22  2005         Birmingham           1             Fulham           2      -1             1.8820         3.2150             3.9410               1.95           3.30               4.33     Pinnacle Sports  Pinnacle Sports              bet365               10           10               10      False    2.400000              10.0                       10.0      1
# 640     171688  England  England: Premier League  2005-01-22  2005            Chelsea           3         Portsmouth           0       1             1.1940         5.6840             9.9220               1.22           6.50               9.99         Sportingbet        BetVictor         bet-at-home               10           10               10      False    3.000000              10.0                       10.0      1
# 641     171689  England  England: Premier League  2005-01-22  2005     Crystal Palace           3          Tottenham           0       1             3.0610         3.2240             2.1830               3.35           3.39               2.25              Expekt  Pinnacle Sports              bet365               10           10               10      False    3.400000              10.0                       10.0      1
# 642     171690  England  England: Premier League  2005-01-22  2005            Everton           0           Charlton           1      -1             1.8300         3.2490             4.1700               2.00           3.30               4.50     Pinnacle Sports      bet-at-home           BetVictor               10           10               10      False    3.600000              10.0                       10.0      1
# 643     171691  England  England: Premier League  2005-01-22  2005  Manchester United           3        Aston Villa           1       1             1.3080         4.4240             9.1710               1.34           5.00               9.99     Pinnacle Sports        BetVictor         bet-at-home               10           10               10      False    3.400000              10.0                       10.0      1
# 644     171692  England  England: Premier League  2005-01-22  2005            Norwich           4      Middlesbrough           4       0             2.9950         3.2100             2.2250               3.35           3.25               2.35              Expekt        BetVictor     Pinnacle Sports               10           10               10      False    3.000000              10.0                       10.0      1
# 645     171693  England  England: Premier League  2005-01-22  2005          West Brom           2    Manchester City           0       1             2.9470         3.2050             2.2500               3.20           3.25               2.38         bet-at-home           bet365               Coral               10           10               10      False    2.400000              10.0                       10.0      1
# 770     171928  England  England: Premier League  2005-01-23  2005            Arsenal           1      Newcastle Utd           0       1             1.4330         3.8460             7.3150               1.50           4.00               8.00              Expekt           bet365           BetVictor               10           10               10      False    7.600000              10.0                       10.0      1
# 843     172116  England  England: Premier League  2005-01-24  2005          Blackburn           0             Bolton           1      -1             2.2500         3.1520             3.0030               2.31           3.25               3.20     Pinnacle Sports      Paddy Power         bet-at-home               10           10               10      False   19.600000              10.0                       10.0      1
# 1153    172838  England  England: Premier League  2005-02-01  2005         Portsmouth           2      Middlesbrough           1       1             2.4830         3.2200             2.6200               2.60           3.25               2.75              bet365            Coral              Expekt               10           10               10      False   17.200000              10.0                       10.0      2
# 1154    172839  England  England: Premier League  2005-02-01  2005          West Brom           2     Crystal Palace           2       0             2.2350         3.2160             2.9560               2.35           3.31               3.25              Expekt  Pinnacle Sports              bet365               10           10               10      False   14.400000              10.0                       10.0      2
# 1155    172840  England  England: Premier League  2005-02-01  2005            Arsenal           2  Manchester United           4      -1             2.2820         3.1260             3.0560               2.45           3.25               3.50              Expekt           Expekt              Expekt               10           10               10      False   10.600000              10.0                       10.0      2
# 1156    172841  England  England: Premier League  2005-02-01  2005             Bolton           3          Tottenham           1       1             2.2100         3.2250             3.0120               2.29           3.30               3.20         Paddy Power        BetVictor         bet-at-home               10           10               10      False    6.600000              10.0                       10.0      2
# 1157    172842  England  England: Premier League  2005-02-01  2005           Charlton           1          Liverpool           2      -1             2.7410         3.1990             2.3840               2.87           3.25               2.50              bet365        BetVictor              Expekt               10           10               10      False    2.800000              10.0                       10.0      2
# 1175    172882  England  England: Premier League  2005-02-02  2005         Birmingham           2        Southampton           1       1             1.8656         3.2822             3.8833               1.91           3.40               4.05               Coral        BetVictor     Pinnacle Sports                9            9                9      False   13.200000               9.8                       10.0      2
# 1176    172883  England  England: Premier League  2005-02-02  2005             Fulham           1        Aston Villa           1       0             2.2489         3.1856             2.9433               2.35           3.30               3.10     Pinnacle Sports        BetVictor              bet365                9            9                9      False   16.800000               9.6                        9.8      2
# 1177    172884  England  England: Premier League  2005-02-02  2005    Manchester City           1      Newcastle Utd           1       0             2.3078         3.2133             2.8400               2.44           3.30               3.00     Pinnacle Sports        BetVictor         bet-at-home                9            9                9      False   14.800000               9.4                        9.6      2
# 1178    172885  England  England: Premier League  2005-02-02  2005          Blackburn           0            Chelsea           1      -1             6.7700         3.7500             1.4667               7.50           4.00               1.50         Paddy Power      Paddy Power              bet365                9            9                9      False   15.600000               9.2                        9.4      2
# 1179    172886  England  England: Premier League  2005-02-02  2005            Everton           1            Norwich           0       1             1.5244         3.5711             6.1722               1.57           3.80               7.00              bet365      bet-at-home              bet365                9            9                9      False   15.000000               9.0                        9.2      2
# 1259    173038  England  England: Premier League  2005-02-05  2005     Crystal Palace           0             Bolton           1      -1             2.5130         3.1900             2.6070               2.70           3.25               2.75     Pinnacle Sports        BetVictor               Coral               10           10               10      False   12.000000               9.2                        9.0      2
# 1260    173039  England  England: Premier League  2005-02-05  2005          Liverpool           3             Fulham           1       1             1.4644         3.7000             7.0078               1.50           4.20               9.00              bet365      bet-at-home         bet-at-home                9            9                9      False   11.666667               9.2                        9.2      2
# 1261    173040  England  England: Premier League  2005-02-05  2005  Manchester United           2         Birmingham           0       1             1.2460         4.9650             9.9000               1.29           5.50               9.99         Sportingbet        BetVictor         bet-at-home               10           10               10      False    9.250000               9.4                        9.2      2
# 1262    173041  England  England: Premier League  2005-02-05  2005      Middlesbrough           1          Blackburn           0       1             1.8900         3.1722             3.9733               2.04           3.25               4.33     Pinnacle Sports        BetVictor               Coral                9            9                9      False    7.600000               9.4                        9.4      2
# 1263    173042  England  England: Premier League  2005-02-05  2005      Newcastle Utd           1           Charlton           1       0             1.7650         3.3490             4.3680               1.80           3.55               4.80         bet-at-home           Expekt              Expekt               10           10               10      False    5.400000               9.6                        9.4      2
# 1264    173043  England  England: Premier League  2005-02-05  2005            Norwich           3          West Brom           2       1             2.2130         3.1780             3.0490               2.34           3.25               3.45     Pinnacle Sports           bet365              Expekt               10           10               10      False    3.600000               9.6                        9.6      2
# 1265    173044  England  England: Premier League  2005-02-05  2005          Tottenham           3         Portsmouth           1       1             1.6844         3.3711             4.8644               1.73           3.60               5.50           Ladbrokes      Sportingbet         Paddy Power                9            9                9      False    1.600000               9.6                        9.6      2
# 1266    173045  England  England: Premier League  2005-02-05  2005        Aston Villa           1            Arsenal           3      -1             4.3560         3.3490             1.7730               5.00           3.40               1.91        William Hill        BetVictor         Paddy Power               10           10               10      False    1.600000               9.6                        9.6      2
# 1386    173283  England  England: Premier League  2005-02-06  2005        Southampton           2            Everton           2       0             2.5910         3.1880             2.5380               2.70           3.25               2.66              Expekt           Expekt     Pinnacle Sports               10           10               10      False    2.000000               9.8                        9.6      2
# 1387    173284  England  England: Premier League  2005-02-06  2005            Chelsea           0    Manchester City           0       0             1.2360         5.1380             9.7600               1.25           5.73               9.99         bet-at-home  Pinnacle Sports         bet-at-home               10           10               10      False    2.000000               9.8                        9.8      2
# 1552    173680  England  England: Premier League  2005-02-12  2005            Everton           0            Chelsea           1      -1             4.4580         3.2450             1.7830               5.35           3.30               1.83              Expekt      bet-at-home              bet365               10           10               10      False    1.000000               9.8                        9.8      2
# 1553    173681  England  England: Premier League  2005-02-12  2005         Birmingham           2          Liverpool           0       1             3.1900         3.1900             2.1400               3.60           3.25               2.20              Expekt        BetVictor              bet365               10           10               10      False    1.000000              10.0                        9.8      2
# 1554    173682  England  England: Premier League  2005-02-12  2005          Blackburn           3            Norwich           0       1             1.7650         3.2540             4.5650               1.83           3.39               5.25               Coral           bet365              Expekt               10           10               10      False    1.000000              10.0                       10.0      2
# 1555    173683  England  England: Premier League  2005-02-12  2005         Portsmouth           1        Aston Villa           2      -1             2.2080         3.2080             3.0240               2.34           3.25               3.20     Pinnacle Sports           bet365         bet-at-home               10           10               10      False    1.000000              10.0                       10.0      2
# 1556    173684  England  England: Premier League  2005-02-12  2005             Bolton           0      Middlesbrough           0       0             2.0544         3.1889             3.3667               2.20           3.25               3.75         Paddy Power      Sportingbet              bet365                9            9                9      False    1.200000               9.8                       10.0      2
# 1681    173961  England  England: Premier League  2005-02-13  2005    Manchester City           0  Manchester United           2      -1             4.6156         3.2478             1.7522               5.00           3.39               1.80              bet365           bet365               Coral                9            9                9      False    1.000000               9.6                        9.8      2
# 1775    174181  England  England: Premier League  2005-02-14  2005            Arsenal           5     Crystal Palace           1       1             1.1960         5.4690             9.9900               1.22           6.00               9.99              bet365           Expekt         bet-at-home               10           10               10      False    1.000000               9.6                        9.6      2
# 2123    175000  England  England: Premier League  2005-02-22  2005          West Brom           0        Southampton           0       0             2.2444         3.2033             2.9411               2.38           3.30               3.00         Paddy Power        BetVictor         bet-at-home                9            9                9      False    4.800000               9.4                        9.6      2
# 2262    175308  England  England: Premier League  2005-02-26  2005        Southampton           1            Arsenal           1       0             5.6630         3.5370             1.5700               6.20           3.60               1.61              Expekt           bet365              bet365               10           10               10      False    6.200000               9.4                        9.4      2
# 2263    175309  England  England: Premier League  2005-02-26  2005        Aston Villa           1            Everton           3      -1             2.1944         3.1611             3.0811               2.25           3.20               3.35              bet365      bet-at-home     Pinnacle Sports                9            9                9      False    6.200000               9.4                        9.4      2
# 2264    175310  England  England: Premier League  2005-02-26  2005     Crystal Palace           2         Birmingham           0       1             2.4811         3.1778             2.6411               2.80           3.20               2.75     Pinnacle Sports      bet-at-home           Ladbrokes                9            9                9      False    5.000000               9.4                        9.4      2
# 2265    175311  England  England: Premier League  2005-02-26  2005          Tottenham           2             Fulham           0       1             1.7780         3.2650             4.4150               1.87           3.35               5.00     Pinnacle Sports           Expekt         Paddy Power               10           10               10      False    3.400000               9.4                        9.4      2
# 2266    175312  England  England: Premier League  2005-02-26  2005  Manchester United           2         Portsmouth           1       1             1.2050         5.4200             9.9900               1.22           6.00               9.99              bet365        BetVictor         bet-at-home               10           10               10      False    2.000000               9.6                        9.4      2
# 2401    175586  England  England: Premier League  2005-02-27  2005      Newcastle Utd           2             Bolton           1       1             1.8730         3.2640             3.9220               1.95           3.40               4.33     Pinnacle Sports        BetVictor         Paddy Power               10           10               10      False    6.600000               9.6                        9.6      2
# 2402    175587  England  England: Premier League  2005-02-27  2005      Middlesbrough           2           Charlton           2       0             1.9000         3.2150             3.8760               2.00           3.25               4.33     Pinnacle Sports      bet-at-home              bet365               10           10               10      False    3.800000               9.8                        9.6      2
# 2494    175827  England  England: Premier League  2005-02-28  2005            Norwich           2    Manchester City           3      -1             2.6367         3.1500             2.5244               2.90           3.25               2.65     Pinnacle Sports            Coral         bet-at-home                9            9                9      False   11.600000               9.8                        9.8      2
# 2613    176130  England  England: Premier League  2005-03-05  2005        Aston Villa           2      Middlesbrough           0       1             2.2510         3.1950             2.9570               2.29           3.25               3.15              bet365           bet365              Expekt               10           10               10      False   11.600000               9.8                        9.8      3
# 2614    176131  England  England: Premier League  2005-03-05  2005            Arsenal           3         Portsmouth           0       1             1.3390         4.2390             8.8240               1.38           4.50               9.99              Expekt        BetVictor              Expekt               10           10               10      False   12.200000               9.8                        9.8      3
# 2615    176132  England  England: Premier League  2005-03-05  2005     Crystal Palace           0  Manchester United           0       0             7.0950         3.7750             1.4500               8.50           4.00               1.50              Expekt           bet365         bet-at-home               10           10               10      False   12.800000               9.8                        9.8      3
# 2616    176133  England  England: Premier League  2005-03-05  2005             Fulham           0           Charlton           0       0             2.2820         3.1800             2.9250               2.38           3.25               3.15               Coral           bet365              Expekt               10           10               10      False   13.400000               9.8                        9.8      3
# 2617    176134  England  England: Premier League  2005-03-05  2005      Newcastle Utd           1          Liverpool           0       1             2.3310         3.1850             2.8420               2.40           3.25               3.00           BetVictor      Sportingbet              Expekt               10           10               10      False   13.400000              10.0                        9.8      3
# 2618    176135  England  England: Premier League  2005-03-05  2005        Southampton           1          Tottenham           0       1             2.4620         3.1830             2.6790               2.50           3.20               2.85         bet-at-home      bet-at-home              Expekt               10           10               10      False   14.800000              10.0                       10.0      3
# 2619    176136  England  England: Premier League  2005-03-05  2005            Norwich           1            Chelsea           3      -1             8.1490         3.9920             1.3850               9.99           4.34               1.40              Expekt        BetVictor         bet-at-home               10           10               10      False   14.800000              10.0                       10.0      3
# 2764    176439  England  England: Premier League  2005-03-06  2005          West Brom           2         Birmingham           0       1             2.5856         3.0978             2.5800               2.75           3.20               2.65              bet365           bet365         bet-at-home                9            9                9      False   13.400000               9.8                       10.0      3
# 2765    176440  England  England: Premier League  2005-03-06  2005            Everton           0          Blackburn           1      -1             1.7200         3.3090             4.7530               1.80           3.40               5.00              Expekt            Coral              bet365               10           10               10      False   15.200000               9.8                        9.8      3
# 2855    176704  England  England: Premier League  2005-03-07  2005    Manchester City           0             Bolton           1      -1             2.3010         3.1560             2.8860               2.50           3.25               3.10     Pinnacle Sports        BetVictor        William Hill               10           10               10      False   14.400000               9.8                        9.8      3
# 3306    177760  England  England: Premier League  2005-03-15  2005            Chelsea           1          West Brom           0       1             1.1536         6.0191             9.9900               1.17           6.50               9.99               Coral           bet365               10Bet               11           11               11      False   18.400000              10.0                        9.8      3
# 3343    177859  England  England: Premier League  2005-03-16  2005           Charlton           2          Tottenham           0       1             2.3173         3.2009             2.8318               2.41           3.25               3.00     Pinnacle Sports           bet365         Paddy Power               11           11               11      False   20.600000              10.2                       10.0      3
# 3344    177860  England  England: Premier League  2005-03-16  2005          Liverpool           0          Blackburn           0       0             1.5400         3.5109             6.1427               1.57           3.85               7.00              bet365           Expekt              Expekt               11           11               11      False   20.400000              10.6                       10.2      3
# 3488    178206  England  England: Premier League  2005-03-19  2005          Blackburn           0            Arsenal           1      -1             4.2660         3.2900             1.7920               4.70           3.40               1.95         bet-at-home            Coral     Pinnacle Sports               10           10               10      False   22.200000              10.6                       10.6      3
# 3489    178207  England  England: Premier League  2005-03-19  2005           Charlton           1          West Brom           4      -1             1.6527         3.4200             5.0273               1.74           3.50               5.65     Pinnacle Sports        BetVictor              Expekt               11           11               11      False   21.400000              10.8                       10.6      3
# 3490    178208  England  England: Premier League  2005-03-19  2005            Chelsea           4     Crystal Palace           1       1             1.1873         5.5891             9.9900               1.20           6.00               9.99         bet-at-home           bet365               10Bet               11           11               11      False   19.800000              10.8                       10.8      3
# 3491    178209  England  England: Premier League  2005-03-19  2005  Manchester United           1             Fulham           0       1             1.2227         5.1855            10.3100               1.25           6.00              14.00         bet-at-home        BetVictor              Expekt               11           11               11      False   20.400000              10.8                       10.8      3
# 3492    178210  England  England: Premier League  2005-03-19  2005         Portsmouth           1      Newcastle Utd           1       0             2.7318         3.1664             2.4209               2.90           3.25               2.54              Expekt        BetVictor              Expekt               11           11               11      False   18.600000              10.8                       10.8      3
# 3493    178211  England  England: Premier League  2005-03-19  2005          Tottenham           2    Manchester City           1       1             1.8191         3.2373             4.2100               1.85           3.40               4.55         bet-at-home        BetVictor              Expekt               11           11               11      False   18.200000              11.0                       10.8      3
# 3494    178212  England  England: Premier League  2005-03-19  2005             Bolton           1            Norwich           0       1             1.5409         3.5300             6.0700               1.57           3.75               7.00              bet365        BetVictor           BetVictor               11           11               11      False   18.600000              11.0                       11.0      3
# 3692    178611  England  England: Premier League  2005-03-20  2005         Birmingham           2        Aston Villa           0       1             2.2955         3.0545             3.0109               2.40           3.20               3.20              Expekt            Coral         bet-at-home               11           11               11      False   13.000000              11.0                       11.0      3
# 3693    178612  England  England: Premier League  2005-03-20  2005      Middlesbrough           1        Southampton           3      -1             1.9650         3.1780             3.6320               2.15           3.25               4.00         bet-at-home      Paddy Power         Paddy Power               10           10               10      False   12.600000              10.8                       11.0      3
# 3694    178613  England  England: Premier League  2005-03-20  2005          Liverpool           2            Everton           1       1             1.8336         3.1627             4.2836               1.91           3.30               5.00               Coral      bet-at-home              bet365               11           11               11      False   12.000000              10.8                       10.8      3
# 4274    180147  England  England: Premier League  2005-04-02  2005           Charlton           2    Manchester City           2       0             2.0640         3.1970             3.3350               2.25           3.25               3.55     Pinnacle Sports      bet-at-home              Expekt               10           10               10      False   12.200000              10.6                       10.8      4
# 4275    180148  England  England: Premier League  2005-04-02  2005            Arsenal           4            Norwich           1       1             1.1764         5.7245             9.9900               1.20           6.04               9.99         bet-at-home  Pinnacle Sports               10Bet               11           11               11      False   11.200000              10.6                       10.6      4
# 4276    180149  England  England: Premier League  2005-04-02  2005         Birmingham           1          Tottenham           1       0             2.2936         3.1809             2.9027               2.38           3.25               3.10         Paddy Power        BetVictor     Pinnacle Sports               11           11               11      False    8.400000              10.6                       10.6      4
# 4277    180150  England  England: Premier League  2005-04-02  2005     Crystal Palace           0      Middlesbrough           1      -1             2.3510         3.1880             2.7720               2.42           3.25               2.89               10Bet        BetVictor              bet365               10           10               10      False    8.600000              10.6                       10.6      4
# 4278    180151  England  England: Premier League  2005-04-02  2005          Liverpool           1             Bolton           0       1             1.8182         3.2236             4.2591               1.90           3.30               4.50              Expekt      bet-at-home              bet365               11           11               11      False    8.800000              10.6                       10.6      4
# 4279    180152  England  England: Premier League  2005-04-02  2005  Manchester United           0          Blackburn           0       0             1.2509         4.8991            10.2391               1.29           5.01              14.00         Sportingbet  Pinnacle Sports              Expekt               11           11               11      False   12.000000              10.8                       10.6      4
# 4280    180153  England  England: Premier League  2005-04-02  2005      Newcastle Utd           0        Aston Villa           3      -1             1.6530         3.3880             5.0520               1.73           3.60               6.00         Paddy Power        BetVictor     Pinnacle Sports               10           10               10      False   10.400000              10.6                       10.8      4
# 4281    180154  England  England: Premier League  2005-04-02  2005        Southampton           1            Chelsea           3      -1             6.0770         3.5000             1.5370               6.50           3.60               1.61              bet365      bet-at-home     Pinnacle Sports               10           10               10      False   11.200000              10.4                       10.6      4
# 4489    180600  England  England: Premier League  2005-04-03  2005             Fulham           3         Portsmouth           1       1             2.0510         3.1960             3.3740               2.25           3.30               3.75     Pinnacle Sports      Sportingbet              bet365               10           10               10      False   21.800000              10.4                       10.4      4
# 4490    180601  England  England: Premier League  2005-04-03  2005          West Brom           1            Everton           0       1             2.6340         3.1870             2.4640               2.75           3.25               2.56              bet365            Coral     Pinnacle Sports               10           10               10      False   21.800000              10.2                       10.4      4
# 4747    181307  England  England: Premier League  2005-04-09  2005          Blackburn           3        Southampton           0       1             2.0018         3.1727             3.5673               2.10           3.25               3.80              bet365        BetVictor         Sportingbet               11           11               11      False   12.400000              10.2                       10.2      4
# 4748    181308  England  England: Premier League  2005-04-09  2005             Bolton           3             Fulham           1       1             1.7173         3.3309             4.6818               1.80           3.40               5.00         Paddy Power        BetVictor              bet365               11           11               11      False   13.000000              10.4                       10.2      4
# 4749    181309  England  England: Premier League  2005-04-09  2005            Chelsea           1         Birmingham           1       0             1.2455         4.9627             9.8436               1.31           5.50               9.99     Pinnacle Sports           bet365         bet-at-home               11           11               11      False   13.200000              10.6                       10.4      4
# ...
# 6093    184580  England  England: Premier League  2005-04-24  2005  Manchester United           2      Newcastle Utd           1       1             1.3170         4.4630             8.4550               1.36           5.00               9.99              bet365        BetVictor     Pinnacle Sports               10           10               10      False   27.200000              10.6                       10.8      4
# 6216    184920  England  England: Premier League  2005-04-25  2005            Arsenal           1          Tottenham           0       1             1.4664         3.6882             6.9564               1.50           4.00               8.25              bet365      Sportingbet              Expekt               11           11               11      False   25.800000              10.6                       10.6      4
# 6230    184957  England  England: Premier League  2005-04-26  2005          West Brom           1          Blackburn           1       0             1.9991         3.2936             3.4327               2.10           3.55               3.80              bet365           Expekt              Expekt               11           11               11      False   25.400000              10.6                       10.6      4
# 6260    185058  England  England: Premier League  2005-04-27  2005      Newcastle Utd           0      Middlesbrough           0       0             2.1080         3.2350             3.1810               2.25           3.30               3.40              bet365     William Hill           Ladbrokes               10           10               10      False   26.400000              10.4                       10.6      4
# 6402    185434  England  England: Premier League  2005-04-30  2005         Birmingham           2          Blackburn           1       1             2.1100         3.1889             3.2500               2.20           3.25               3.70              bet365      Paddy Power              Expekt                9            9                9      False   27.200000              10.2                       10.4      4
# 6403    185435  England  England: Premier League  2005-04-30  2005             Fulham           2            Everton           0       1             2.6900         3.2000             2.4233               2.85           3.40               2.60              Expekt            Coral              Expekt                9            9                9      False   27.200000              10.0                       10.2      4
# 6404    185436  England  England: Premier League  2005-04-30  2005          Liverpool           1      Middlesbrough           1       0             1.6910         3.3930             4.7780               1.80           3.50               5.50              Expekt        Ladbrokes         Paddy Power               10           10               10      False   27.000000               9.8                       10.0      4
# 6405    185437  England  England: Premier League  2005-04-30  2005    Manchester City           2         Portsmouth           0       1             1.7490         3.3260             4.4310               1.83           3.45               5.09         Paddy Power           Expekt              Expekt               10           10               10      False   26.800000               9.6                        9.8      4
# 6406    185438  England  England: Premier League  2005-04-30  2005      Newcastle Utd           0     Crystal Palace           0       0             1.8160         3.3690             3.9090               1.95           3.50               4.33              Expekt        Ladbrokes              bet365               10           10               10      False   27.000000               9.6                        9.6      4
# 6407    185439  England  England: Premier League  2005-04-30  2005        Southampton           4            Norwich           3       1             2.0260         3.3100             3.3210               2.15           3.50               3.60        William Hill            Coral              Expekt               10           10               10      False   27.000000               9.8                        9.6      4
# 6408    185440  England  England: Premier League  2005-04-30  2005             Bolton           0            Chelsea           2      -1             3.6250         3.2250             1.9225               3.70           3.30               2.10         bet-at-home      bet-at-home              Expekt                4            4                4      False   27.000000               8.8                        9.8      4
# 6579    185909  England  England: Premier League  2005-05-01  2005          Tottenham           5        Aston Villa           1       1             1.9009         3.2845             3.7691               2.00           3.40               4.20           Ladbrokes            Coral              Expekt               11           11               11      False   27.200000               9.0                        8.8      5
# 6580    185910  England  England: Premier League  2005-05-01  2005           Charlton           0  Manchester United           4      -1             5.2800         3.5680             1.5820               6.00           3.75               1.65              bet365        BetVictor         bet-at-home               10           10               10      False   27.000000               9.0                        9.0      5
# 6678    186159  England  England: Premier League  2005-05-02  2005          West Brom           0            Arsenal           2      -1             5.7000         3.5760             1.5430               6.50           3.65               1.57         Sportingbet  Pinnacle Sports              bet365               10           10               10      False   26.400000               9.0                        9.0      5
# 6716    186300  England  England: Premier League  2005-05-04  2005             Fulham           1      Newcastle Utd           3      -1             2.1691         3.1945             3.1055               2.25           3.25               3.30         Paddy Power           bet365           BetVictor               11           11               11      False   25.400000               9.2                        9.0      5
# 6885    186700  England  England: Premier League  2005-05-07  2005        Aston Villa           1    Manchester City           2      -1             2.2491         3.2445             2.8882               2.37           3.30               3.10              bet365        BetVictor              Expekt               11           11               11      False   26.000000              10.6                        9.2      5
# 6886    186701  England  England: Premier League  2005-05-07  2005          Blackburn           1             Fulham           3      -1             1.9873         3.2073             3.5264               2.10           3.25               3.90              bet365           bet365              Expekt               11           11               11      False   25.800000              10.6                       10.6      5
# 6887    186702  England  England: Premier League  2005-05-07  2005            Chelsea           1           Charlton           0       1             1.2936         4.5127             9.3027               1.36           5.00               9.99     Pinnacle Sports           bet365         bet-at-home               11           11               11      False   25.800000              10.8                       10.6      5
# 6888    186703  England  England: Premier League  2005-05-07  2005     Crystal Palace           2        Southampton           2       0             2.1636         3.2582             3.0409               2.25           3.40               3.25         Paddy Power        BetVictor     Pinnacle Sports               11           11               11      False   26.400000              11.0                       10.8      5
# 6889    186704  England  England: Premier League  2005-05-07  2005            Everton           2      Newcastle Utd           0       1             1.6845         3.3582             4.7936               1.75           3.50               5.35         bet-at-home        BetVictor              Expekt               11           11               11      False   26.000000              11.0                       11.0      5
# 6890    186705  England  England: Premier League  2005-05-07  2005      Middlesbrough           1          Tottenham           0       1             2.2445         3.2000             2.9400               2.35           3.25               3.20           BetVictor            Coral         Sportingbet               11           11               11      False   26.000000              11.0                       11.0      5
# 6891    186706  England  England: Premier League  2005-05-07  2005            Norwich           1         Birmingham           0       1             1.8409         3.4391             3.7636               1.91           3.75               4.30           Ladbrokes           Expekt              Expekt               11           11               11      False   26.200000              11.0                       11.0      5
# 6892    186707  England  England: Premier League  2005-05-07  2005         Portsmouth           1             Bolton           1       0             2.7809         3.2673             2.3045               3.10           3.40               2.50              Expekt            Coral         Paddy Power               11           11               11      False   26.600000              11.0                       11.0      5
# 6893    186708  England  England: Premier League  2005-05-07  2005  Manchester United           1          West Brom           1       0             1.2933         4.8500             8.8311               1.33           5.65               9.99               Coral           Expekt         bet-at-home                9            9                9      False   26.600000              10.6                       11.0      5
# 7062    187083  England  England: Premier League  2005-05-08  2005            Arsenal           3          Liverpool           1       1             1.7140         3.4090             4.5000               1.80           3.50               5.00              bet365            Coral           BetVictor               10           10               10      False   27.600000              10.4                       10.6      5
# 7229    187476  England  England: Premier League  2005-05-10  2005  Manchester United           1            Chelsea           3      -1             2.1110         3.2010             3.1630               2.20           3.40               3.40         Paddy Power            Coral           BetVictor               10           10               10      False    6.200000              10.2                       10.4      5
# 7249    187581  England  England: Premier League  2005-05-11  2005            Arsenal           7            Everton           0       1             1.4690         3.7050             6.5890               1.53           4.00               7.00              bet365      Paddy Power           BetVictor               10           10               10      False    9.400000              10.0                       10.2      5
# 7494    188217  England  England: Premier League  2005-05-15  2005         Birmingham           2            Arsenal           1       1             4.0400         3.4050             1.7860               4.50           3.50               1.91         Paddy Power           bet365               Coral               10           10               10      False   10.400000               9.8                       10.0      5
# 7495    188218  England  England: Premier League  2005-05-15  2005             Bolton           3            Everton           2       1             1.8390         3.3340             3.9470               1.91           3.40               4.50               Coral        BetVictor              bet365               10           10               10      False    9.800000              10.0                        9.8      5
# 7496    188219  England  England: Premier League  2005-05-15  2005           Charlton           2     Crystal Palace           2       0             2.6570         3.4740             2.2850               2.88           3.60               2.45         Sportingbet        BetVictor     Pinnacle Sports               10           10               10      False    8.800000              10.0                       10.0      5
# 7497    188220  England  England: Premier League  2005-05-15  2005             Fulham           6            Norwich           0       1             2.6318         3.4482             2.3482               2.75           3.60               2.50              bet365           Expekt         Paddy Power               11           11               11      False    8.600000              10.2                       10.0      5
# 7498    188221  England  England: Premier League  2005-05-15  2005          Liverpool           2        Aston Villa           1       1             1.6364         3.4118             5.2100               1.70           3.55               6.00        William Hill           Expekt              Expekt               11           11               11      False    8.800000              10.4                       10.2      5
# 7499    188222  England  England: Premier League  2005-05-15  2005    Manchester City           1      Middlesbrough           1       0             2.0050         3.1480             3.5260               2.10           3.25               3.75              bet365      Paddy Power           BetVictor               10           10               10      False    9.000000              10.4                       10.4      5
# 7500    188223  England  England: Premier League  2005-05-15  2005      Newcastle Utd           1            Chelsea           1       0             3.3473         3.3400             2.0127               4.00           3.40               2.20              Expekt        BetVictor               Coral               11           11               11      False   10.000000              10.6                       10.4      5
# 7501    188224  England  England: Premier League  2005-05-15  2005        Southampton           1  Manchester United           2      -1             2.4860         3.5240             2.4080               2.85           3.60               2.50     Pinnacle Sports           bet365         bet-at-home               10           10               10       True   11.200000              10.6                       10.6      5
# 7502    188225  England  England: Premier League  2005-05-15  2005          Tottenham           0          Blackburn           0       0             1.5282         3.5964             5.9836               1.61           3.75               7.00         Paddy Power           Expekt           Ladbrokes               11           11               11      False   11.800000              10.6                       10.6      5
# 7503    188226  England  England: Premier League  2005-05-15  2005          West Brom           2         Portsmouth           0       1             1.5436         3.7382             5.5155               1.60           4.25               6.25         bet-at-home  Pinnacle Sports     Pinnacle Sports               11           11               11      False   11.400000              10.6                       10.6      5

# %% [markdown]
# Out of these 180 games, only 1 was advantageous to bet on. (The last one)

# %%
Closing_Odds[
    (Closing_Odds['league']=="England: Premier League")&
    (Closing_Odds['year']<=2005)&
    (Closing_Odds['month']<=7)]['condition'].sum()
# Out:
# 1

# %% [markdown]
# So, the first PL game of the 2006-07 season will have a cond_est of 1/180, which is 0.0056
#
# Now that the process is clear, let's dive into the code.

# %%
def calculate_league_condition_ratio(df: pd.DataFrame) -> pd.Series:
    
    condition_ratios = []  # Store calculated ratios
    league_history = {}  # History of conditions for each league

    for _, row in df.iterrows():
        league = row['league']
        condition = row['condition']

        # Initialize league history if not present
        if league not in league_history:
            league_history[league] = []

        # Retrieve previous conditions for the league
        previous_conditions = league_history[league]

        # Calculate the condition ratio
        condition_ratio = sum(previous_conditions) / len(previous_conditions) if previous_conditions else 0

        # Update the league history and ratios
        previous_conditions.append(condition)
        condition_ratios.append(condition_ratio)

    return pd.Series(condition_ratios, name='condition_ratio')

League_Cond_Ratio = calculate_league_condition_ratio(Closing_Odds)

# %%
League_Cond_Ratio
# Out:
# 0         0.000000
# 1         0.000000
# 2         0.000000
# 3         0.000000
# 4         0.000000
#             ...
# 479435    0.138004
# 479436    0.137995
# 479437    0.137985
# 479438    0.137975
# 479439    0.137965
# Name: condition_ratio, Length: 479440, dtype: float64

# %%
Closing_Odds['league_condition_est'] = League_Cond_Ratio

# %%
# Final Dataframe : 
Closing_Odds
# Out:
#         match_id  country                   league  match_date  year     home_team  home_score          away_team  away_score  result  avg_odds_home_win  avg_odds_draw  avg_odds_away_win  max_odds_home_win  max_odds_draw  max_odds_away_win top_bookie_home_win  top_bookie_draw top_bookie_away_win  n_odds_home_win  n_odds_draw  n_odds_away_win  condition  n_odds_est  n_odds_est_fixed  n_odds_est_fixed_with_lag  month  league_condition_est
# 0         170088  England  England: Premier League  2005-01-01  2005     Liverpool           0            Chelsea           1      -1             2.9944         3.1944             2.2256               3.20           3.25               2.29         Paddy Power      Sportingbet              Expekt                9            9                9      False        19.0               9.0                        NaN      1              0.000000
# 1         170089  England  England: Premier League  2005-01-01  2005        Fulham           3     Crystal Palace           1       1             1.9456         3.2333             3.6722               2.04           3.30               4.15     Pinnacle Sports      bet-at-home              Expekt                9            9                9      False        14.0               9.0                        9.0      1              0.000000
# 2         170090  England  England: Premier League  2005-01-01  2005   Aston Villa           1          Blackburn           0       1             1.8522         3.2611             4.0144               2.00           3.40               4.50     Pinnacle Sports      Paddy Power         Sportingbet                9            9                9      False        16.0               9.0                        9.0      1              0.000000
# 3         170091  England  England: Premier League  2005-01-01  2005        Bolton           1          West Brom           1       0             1.6122         3.4133             5.4722               1.67           3.57               6.27               Coral  Pinnacle Sports     Pinnacle Sports                9            9                9      False        17.0               9.0                        9.0      1              0.000000
# 4         170092  England  England: Premier League  2005-01-01  2005      Charlton           1            Arsenal           3      -1             5.9878         3.4778             1.5567               7.00           3.60               1.62              Expekt      Paddy Power              bet365                9            9                9      False        17.6               9.0                        9.0      1              0.000000
# ...          ...      ...                      ...         ...   ...           ...         ...                ...         ...     ...                ...            ...                ...                ...            ...                ...                 ...              ...                 ...              ...          ...              ...        ...         ...               ...                        ...    ...                   ...
# 479435    876806    World     World: Club Friendly  2015-06-30  2015    St. Gallen           1   Wacker Innsbruck           2      -1             1.6838         3.8846             3.9813               1.83           4.20               4.33              188BET           bet365           Ladbrokes               24           24               24      False        12.0              15.8                       15.4      6              0.138004
# 479436    876807    World     World: Club Friendly  2015-06-30  2015  SW Harelbeke           1            Waregem           1       0            13.1165         7.8229             1.1053              19.00           9.00               1.13           BetVictor           bet365            Titanbet               17           17               17      False        11.8              16.2                       15.8      6              0.137995
# 479437    876808    World     World: Club Friendly  2015-06-30  2015       Torhout           0        Club Brugge           5      -1            17.2256        12.6231             1.0288              22.00          15.00               1.05           BetVictor          Jetbull           BetVictor               16           16               16      False        11.6              14.0                       16.2      6              0.137985
# 479438    876809    World     World: Club Friendly  2015-06-30  2015       Tournai           0  Mouscron Peruwelz           3      -1            15.7143        10.2857             1.0614              34.00          12.00               1.10         Sportingbet          Betclic         Paddy Power                7            7                7      False        11.2              15.0                       14.0      6              0.137975
# 479439    876812    World     World: Club Friendly  2015-06-30  2015         Zavrc           0         Istra 1961           0       0             4.7145         3.9259             1.5650               5.46           4.25               1.70     Pinnacle Sports         888sport           Ladbrokes               22           22               22       True         1.0              17.2                       15.0      6              0.137965
#
# [479440 rows x 28 columns]

# %%
Closing_Odds.loc[:, ["league", "match_id", "match_date", "condition", "league_condition_est"]].head(10)
# Out:
#                     league  match_id  match_date  condition  league_condition_est
# 0  England: Premier League    170088  2005-01-01      False                   0.0
# 1  England: Premier League    170089  2005-01-01      False                   0.0
# 2  England: Premier League    170090  2005-01-01      False                   0.0
# 3  England: Premier League    170091  2005-01-01      False                   0.0
# 4  England: Premier League    170092  2005-01-01      False                   0.0
# 5  England: Premier League    170093  2005-01-01      False                   0.0
# 6  England: Premier League    170094  2005-01-01      False                   0.0
# 7  England: Premier League    170095  2005-01-01      False                   0.0
# 8  England: Premier League    170096  2005-01-01      False                   0.0
# 9  England: Premier League    170097  2005-01-01      False                   0.0

# %%
Closing_Odds.loc[Closing_Odds.condition==True, ["league", "match_id", "match_date", "condition", "league_condition_est"]].head(10)
# Out:
#                       league  match_id  match_date  condition  league_condition_est
# 24       England: League One    170112  2005-01-01       True              0.000000
# 84     England: Championship    170235  2005-01-03       True              0.000000
# 85     England: Championship    170236  2005-01-03       True              0.058824
# 148  Spain: Primera Division    170366  2005-01-05       True              0.000000
# 151           Italy: Serie A    170382  2005-01-06       True              0.000000
# 171  France: Coupe de France    170458  2005-01-07       True              0.000000
# 173  France: Coupe de France    170460  2005-01-07       True              0.333333
# 225          England: FA Cup    170580  2005-01-08       True              0.000000
# 277          England: FA Cup    170670  2005-01-09       True              0.033333
# 305  Portugal: Primeira Liga    170776  2005-01-09       True              0.000000

# %%
Closing_Odds.loc[Closing_Odds.league=="England: Championship", ["league", "match_id", "match_date", "condition", "league_condition_est"]].head(20)
# Out:
#                    league  match_id  match_date  condition  league_condition_est
# 10  England: Championship    170098  2005-01-01      False              0.000000
# 11  England: Championship    170099  2005-01-01      False              0.000000
# 12  England: Championship    170100  2005-01-01      False              0.000000
# 13  England: Championship    170101  2005-01-01      False              0.000000
# 14  England: Championship    170102  2005-01-01      False              0.000000
# 15  England: Championship    170103  2005-01-01      False              0.000000
# 16  England: Championship    170104  2005-01-01      False              0.000000
# 17  England: Championship    170105  2005-01-01      False              0.000000
# 18  England: Championship    170106  2005-01-01      False              0.000000
# 19  England: Championship    170107  2005-01-01      False              0.000000
# 20  England: Championship    170108  2005-01-01      False              0.000000
# 79  England: Championship    170230  2005-01-03      False              0.000000
# 80  England: Championship    170231  2005-01-03      False              0.000000
# 81  England: Championship    170232  2005-01-03      False              0.000000
# 82  England: Championship    170233  2005-01-03      False              0.000000
# 83  England: Championship    170234  2005-01-03      False              0.000000
# 84  England: Championship    170235  2005-01-03       True              0.000000
# 85  England: Championship    170236  2005-01-03       True              0.058824
# 86  England: Championship    170237  2005-01-03      False              0.111111
# 87  England: Championship    170238  2005-01-03      False              0.105263

# %%
1/17
# Out:
# 0.058823529411764705

# %%
Closing_Odds.loc[Closing_Odds.league=="Africa: Africa Cup of Nations", :].head(10)
# Out:
#        match_id country                         league  match_date  year    home_team  home_score     away_team  away_score  result  avg_odds_home_win  avg_odds_draw  avg_odds_away_win  max_odds_home_win  max_odds_draw  max_odds_away_win top_bookie_home_win  top_bookie_draw top_bookie_away_win  n_odds_home_win  n_odds_draw  n_odds_away_win  condition  n_odds_est  n_odds_est_fixed  n_odds_est_fixed_with_lag  month  league_condition_est
# 71890    316345  Africa  Africa: Africa Cup of Nations  2008-01-29  2008  Ivory Coast           3          Mali           0       1             2.3847         1.9226             6.4137               2.54           2.00               8.30             Betsafe      bet-at-home              188BET               19           19               19      False        21.0              19.0                        NaN      1              0.000000
# 71891    316346  Africa  Africa: Africa Cup of Nations  2008-01-29  2008      Nigeria           2         Benin           0       1             1.2078         5.4500            11.7822               1.25           6.00              15.00                bwin           Expekt              bet365                9            9                9      False        21.2              14.0                       19.0      1              0.000000
# 71947    316426  Africa  Africa: Africa Cup of Nations  2008-01-30  2008     Cameroon           3         Sudan           0       1             1.1005         7.5075            17.4000               1.12           9.00              25.00              Betway           bet365              Unibet               20           20               20      False        19.8              16.0                       14.0      1              0.000000
# 71948    316427  Africa  Africa: Africa Cup of Nations  2008-01-30  2008        Egypt           1        Zambia           1       0             1.3955         4.5025            15.3740               1.53           9.00             101.00              188BET     William Hill         Sportingbet               20           20               20       True        20.2              17.0                       16.0      1              0.000000
# 71988    316479  Africa  Africa: Africa Cup of Nations  2008-01-31  2008      Senegal           1  South Africa           1       0             1.8190         3.4025             3.9870               1.90           3.70               4.55         bet-at-home  Pinnacle Sports              188BET               20           20               20      False        23.6              17.6                       17.0      1              0.250000
# 71989    316480  Africa  Africa: Africa Cup of Nations  2008-01-31  2008      Tunisia           0        Angola           0       0             2.9115         1.7755             5.1730               3.20           1.90               5.80         bet-at-home           Betway              Unibet               20           20               20      False        23.4              17.8                       17.6      1              0.200000
# 72195    316805  Africa  Africa: Africa Cup of Nations  2008-02-03  2008        Ghana           2       Nigeria           1       1             1.8670         3.1945             4.1575               2.00           3.25               4.95         bet-at-home           188BET              188BET               20           20               20      False        25.8              20.0                       17.8      2              0.166667
# 72196    316806  Africa  Africa: Africa Cup of Nations  2008-02-03  2008  Ivory Coast           5        Guinea           0       1             1.3530         4.1080             9.1715               1.50           4.50              11.00         bet-at-home           bet365              bet365               20           20               20       True        25.6              20.0                       20.0      2              0.142857
# 72311    317008  Africa  Africa: Africa Cup of Nations  2008-02-04  2008        Egypt           2        Angola           1       1             1.7653         3.3174             4.5558               2.00           3.45               5.25         bet-at-home           188BET              bet365               19           19               19       True        27.4              19.8                       20.0      2              0.250000
# 72312    317009  Africa  Africa: Africa Cup of Nations  2008-02-04  2008      Tunisia           2      Cameroon           2       0             3.7411         3.1747             1.9895               4.33           3.30               2.20           Ladbrokes           188BET         bet-at-home               19           19               19      False        27.6              19.6                       19.8      2              0.333333

# %%
# Final Dataframe from Remi's solution: 
Closing_Odds
# Out:
#         match_id  country                   league  match_date  year     home_team  home_score          away_team  away_score  result  avg_odds_home_win  avg_odds_draw  avg_odds_away_win  max_odds_home_win  max_odds_draw  max_odds_away_win top_bookie_home_win  top_bookie_draw top_bookie_away_win  n_odds_home_win  n_odds_draw  n_odds_away_win  condition  n_odds_est  n_odds_est_fixed  n_odds_est_fixed_with_lag  month  league_condition_est
# 0         170088  England  England: Premier League  2005-01-01  2005     Liverpool           0            Chelsea           1      -1             2.9944         3.1944             2.2256               3.20           3.25               2.29         Paddy Power      Sportingbet              Expekt                9            9                9      False        19.0               9.0                        NaN      1              0.000000
# 1         170089  England  England: Premier League  2005-01-01  2005        Fulham           3     Crystal Palace           1       1             1.9456         3.2333             3.6722               2.04           3.30               4.15     Pinnacle Sports      bet-at-home              Expekt                9            9                9      False        14.0               9.0                        9.0      1              0.000000
# 2         170090  England  England: Premier League  2005-01-01  2005   Aston Villa           1          Blackburn           0       1             1.8522         3.2611             4.0144               2.00           3.40               4.50     Pinnacle Sports      Paddy Power         Sportingbet                9            9                9      False        16.0               9.0                        9.0      1              0.000000
# 3         170091  England  England: Premier League  2005-01-01  2005        Bolton           1          West Brom           1       0             1.6122         3.4133             5.4722               1.67           3.57               6.27               Coral  Pinnacle Sports     Pinnacle Sports                9            9                9      False        17.0               9.0                        9.0      1              0.000000
# 4         170092  England  England: Premier League  2005-01-01  2005      Charlton           1            Arsenal           3      -1             5.9878         3.4778             1.5567               7.00           3.60               1.62              Expekt      Paddy Power              bet365                9            9                9      False        17.6               9.0                        9.0      1              0.000000
# ...          ...      ...                      ...         ...   ...           ...         ...                ...         ...     ...                ...            ...                ...                ...            ...                ...                 ...              ...                 ...              ...          ...              ...        ...         ...               ...                        ...    ...                   ...
# 479435    876806    World     World: Club Friendly  2015-06-30  2015    St. Gallen           1   Wacker Innsbruck           2      -1             1.6838         3.8846             3.9813               1.83           4.20               4.33              188BET           bet365           Ladbrokes               24           24               24      False        12.0              15.8                       15.4      6              0.138004
# 479436    876807    World     World: Club Friendly  2015-06-30  2015  SW Harelbeke           1            Waregem           1       0            13.1165         7.8229             1.1053              19.00           9.00               1.13           BetVictor           bet365            Titanbet               17           17               17      False        11.8              16.2                       15.8      6              0.137995
# 479437    876808    World     World: Club Friendly  2015-06-30  2015       Torhout           0        Club Brugge           5      -1            17.2256        12.6231             1.0288              22.00          15.00               1.05           BetVictor          Jetbull           BetVictor               16           16               16      False        11.6              14.0                       16.2      6              0.137985
# 479438    876809    World     World: Club Friendly  2015-06-30  2015       Tournai           0  Mouscron Peruwelz           3      -1            15.7143        10.2857             1.0614              34.00          12.00               1.10         Sportingbet          Betclic         Paddy Power                7            7                7      False        11.2              15.0                       14.0      6              0.137975
# 479439    876812    World     World: Club Friendly  2015-06-30  2015         Zavrc           0         Istra 1961           0       0             4.7145         3.9259             1.5650               5.46           4.25               1.70     Pinnacle Sports         888sport           Ladbrokes               22           22               22       True         1.0              17.2                       15.0      6              0.137965
#
# [479440 rows x 28 columns]

# %% [markdown]
# ## III - Model Choice

# %% [markdown]
# Our goal now is to build an AI model to predict the condition label for our games, to follow our betting strategy optimally.
#
# We also only take into account features we can use both for training AND testing. Meaning we simply discard odds data, results, goal difference ...
#
# It's a first approximation, we shall see whether or not to improve the model based on preliminary results, and find ways to include more data, or new ways of slicing data to mitigate issues and biases.
#
# Also, and although it hurts because they are very correlated with our label, we cannot include year and match_id in our model, as our use case revolves around the fact that we shouldn't be able to

# %%
training_columns = (["month","league_condition_est","n_odds_est"])

# %%
# mznote: original solution

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import roc_auc_score, classification_report
import sklearn.metrics as metrics


# Split our data into features and labels
X = Closing_Odds[training_columns]
y = Closing_Odds['condition']

# Split into train/test sets with 20% of games as testing and 80% as training

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Let's take a classic Decision Tree for now. Explainable, handles classs imbalance and intuitive 
model = DecisionTreeClassifier(random_state = 77, class_weight='balanced', max_depth=4)

# Train the model
model.fit(X_train, y_train)

# Predict probabilities for AUC-ROC
y_pred_proba = model.predict_proba(X_test)[:, 1]

# Evaluate
fpr, tpr, threshold = metrics.roc_curve(y_test, y_pred_proba)
roc_auc = metrics.auc(fpr, tpr)
auc = roc_auc_score(y_test, y_pred_proba)
print(f'AUC-ROC: {auc:.4f}')

pl.title('Receiver Operating Characteristic')
pl.plot(fpr, tpr, 'r', label = 'AUC = %0.2f' % roc_auc)
pl.legend(loc = 'lower right')
pl.plot([0, 1], [0, 1],color = 'black',linestyle='--')
pl.xlim([0, 1])
pl.ylim([0, 1])
pl.ylabel('True Positive Rate')
pl.xlabel('False Positive Rate')
pl.show()

# Also, print a classification report
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
print(model.feature_importances_)
# Out:
# AUC-ROC: 0.5315
#               precision    recall  f1-score   support
#
#        False       0.89      0.51      0.65    126902
#         True       0.13      0.53      0.20     16930
#
#     accuracy                           0.51    143832
#    macro avg       0.51      0.52      0.43    143832
# weighted avg       0.80      0.51      0.60    143832
#
# [0.26972529 0.52244355 0.20783115]

# %% [markdown]
# #### This model has an AUC of .535, and it correctly retrieves 64% of the games fulfilling the paper's condition. This is a great first step, and a gives us hope that with a better data pipeline, we can leverage more data (odds, mainly) into the training/testing processes to bolster these results in the future.

# %%
fig = pl.figure(figsize=(60,15))
_ = tree.plot_tree(model,feature_names=X.columns,class_names=['False','True'], filled=True)

# %%
# mznote:
# interpret [0.26972529 0.52244355 0.20783115] feature_importances_
# interpret gini in tree plot
# trin/test split: random, while "league_condition_est","n_odds_est" are sorted in match_id (time) - which split would be more appropriate?

# %%
# mznote: below are results from dataset with fixed indexing

# %%
Closing_Odds.columns
# Out:
# Index(['match_id', 'country', 'league', 'match_date', 'year', 'home_team', 'home_score', 'away_team', 'away_score', 'result', 'avg_odds_home_win', 'avg_odds_draw', 'avg_odds_away_win', 'max_odds_home_win', 'max_odds_draw', 'max_odds_away_win', 'top_bookie_home_win', 'top_bookie_draw', 'top_bookie_away_win', 'n_odds_home_win', 'n_odds_draw', 'n_odds_away_win', 'condition', 'n_odds_est', 'n_odds_est_fixed', 'n_odds_est_fixed_with_lag', 'month', 'league_condition_est'], dtype='object')

# %%
training_columns = (["month","league_condition_est","n_odds_est_fixed"])

# %%
# Split our data into features and labels
X = Closing_Odds[training_columns]
y = Closing_Odds['condition']

# Split into train/test sets with 20% of games as testing and 80% as training

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Let's take a classic Decision Tree for now. Explainable, handles classs imbalance and intuitive 
model = DecisionTreeClassifier(random_state = 77, class_weight='balanced', max_depth=4)

# Train the model
model.fit(X_train, y_train)

# Predict probabilities for AUC-ROC
y_pred_proba = model.predict_proba(X_test)[:, 1]

# Evaluate
fpr, tpr, threshold = metrics.roc_curve(y_test, y_pred_proba)
roc_auc = metrics.auc(fpr, tpr)
auc = roc_auc_score(y_test, y_pred_proba)
print(f'AUC-ROC: {auc:.4f}')

pl.title('Receiver Operating Characteristic')
pl.plot(fpr, tpr, 'r', label = 'AUC = %0.2f' % roc_auc)
pl.legend(loc = 'lower right')
pl.plot([0, 1], [0, 1],color = 'black',linestyle='--')
pl.xlim([0, 1])
pl.ylim([0, 1])
pl.ylabel('True Positive Rate')
pl.xlabel('False Positive Rate')
pl.show()

# Also, print a classification report
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
print(model.feature_importances_)
# Out:
# AUC-ROC: 0.6737
#               precision    recall  f1-score   support
#
#        False       0.94      0.48      0.64    126902
#         True       0.17      0.78      0.28     16930
#
#     accuracy                           0.52    143832
#    macro avg       0.56      0.63      0.46    143832
# weighted avg       0.85      0.52      0.59    143832
#
# [0.         0.78186645 0.21813355]

# %%
# mznote: what is wrong with this solution? lag

# %%
training_columns = (["month","league_condition_est","n_odds_est_fixed_with_lag"])
# Split our data into features and labels
X = Closing_Odds[training_columns]
y = Closing_Odds['condition']

# Split into train/test sets with 20% of games as testing and 80% as training

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Let's take a classic Decision Tree for now. Explainable, handles classs imbalance and intuitive 
model = DecisionTreeClassifier(random_state = 77, class_weight='balanced', max_depth=4)

# Train the model
model.fit(X_train, y_train)

# Predict probabilities for AUC-ROC
y_pred_proba = model.predict_proba(X_test)[:, 1]

# Evaluate
fpr, tpr, threshold = metrics.roc_curve(y_test, y_pred_proba)
roc_auc = metrics.auc(fpr, tpr)
auc = roc_auc_score(y_test, y_pred_proba)
print(f'AUC-ROC: {auc:.4f}')

pl.title('Receiver Operating Characteristic')
pl.plot(fpr, tpr, 'r', label = 'AUC = %0.2f' % roc_auc)
pl.legend(loc = 'lower right')
pl.plot([0, 1], [0, 1],color = 'black',linestyle='--')
pl.xlim([0, 1])
pl.ylim([0, 1])
pl.ylabel('True Positive Rate')
pl.xlabel('False Positive Rate')
pl.show()

# Also, print a classification report
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
print(model.feature_importances_)
# Out:
# AUC-ROC: 0.6758
#               precision    recall  f1-score   support
#
#        False       0.94      0.47      0.63    126902
#         True       0.17      0.79      0.27     16930
#
#     accuracy                           0.51    143832
#    macro avg       0.56      0.63      0.45    143832
# weighted avg       0.85      0.51      0.59    143832
#
# [0.         0.82903107 0.17096893]

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[59813, 67089],
#        [ 3538, 13392]])

# %%
# precision = TP/(TP+FP)
# recall = TP/P
precision = 59813/(59813+3538)
recall = 59813/(59813+67089)
print(precision, recall)
# Out:
# 0.9441524206405582 0.47133220910623946

# %%
# mznote: ideas for features: check volatility in odds for past matches of a home_team win/away_team win/draw across home_team/away_team/league; check how often condition was satisfied in previous matches in home_team/away_team/league level

# %% [markdown]
# ## Conclusion :

# %% [markdown]
# This time, the model is even better, with better features, more explainability, and less complexity.
#
# It might be beneficial to try other types of models, like XGBoost for example. I didn't want to take that route based on what you advised.

# %% [markdown]
# I did my best to follow your feedback, and still stay true to the original paper's vision, which is to stay away from the idea of trying to predict games' results and instead focus solely on bookmakers' odd distribution.
#
# I hope you like it better this time.

# %% [markdown]
# #### Below are features AI hinted at, or features I tried to include and ultimately didn't keep.
#
# What Chatbots hinted at. I don't see anything that doesn't fall into 1 of 3 categories :
# - I tried it
# - It clashes with the idea of the paper, which is to stay as far as we can from trying to predict games' results
# - It can't be done with our data
#
# Also, most of them would fall in the "previous solution was too complicated, simplify" category. I would've maybe liked to try some, but I feared it would've meant going directly against what you advised me to do.
#
# Let me know if I missed something, I will listen carefully to your feedback.

# %% [markdown]
# ### Team Performance Features
# ##### Historical Win/Loss/Draw Rates:
#
# Home Team Win Rate
#
# Away Team Win Rate
#
# Home Team Draw Rate
#
# Away Team Draw Rate
#
#
# ##### Goals Scored and Conceded:
#
# Average Goals Scored (Home)
#
# Average Goals Conceded (Home)
#
# Average Goals Scored (Away)
#
# Average Goals Conceded (Away)
#
# ### Recent Form:
#
# Home Team Recent Form
#
# Away Team Recent Form
#
# ### Head-to-Head Features
# ##### Head-to-Head Win/Loss/Draw Rates:
#
# Home Team Win Rate vs. Away Team
#
# Away Team Win Rate vs. Home Team
#
# Draw Rate
#
# ##### Head-to-Head Goals Scored and Conceded:
#
# Average Goals Scored by Home Team vs. Away Team
#
# Average Goals Conceded by Home Team vs. Away Team
#
# Average Goals Scored by Away Team vs. Home Team
#
# Average Goals Conceded by Away Team vs. Home Team
#
#
#
# ### League-Specific Features
# ##### League Performance:
#
# Home Team League Position
#
# Away Team League Position
#
# League Average Goals
#
# ##### League Strength:
#
# League Strength Indicator: A metric indicating the overall strength of the league (e.g., average goals per match, win/loss rates).
#
#
# ### Time-Based Features
# ##### Time Since Last Match:
#
# Days Since Last Match (Home)
#
# Days Since Last Match (Away)
#
# ##### Match Timing:
#
# Day of the Week
#
# Month
#
#
#
# ### Team-Specific Features
# ##### Home/Away Performance:
#
# Home Team Home Performance
#
# Away Team Away Performance
#
#
# ##### Team Strength Indicators:
#
# Home Team Strength : composite metric indicating the overall strength of the home team (e.g., based on historical performance, goals scored, etc.)
# Away Team Strength

# %% [markdown]
# ### Features I tried to implement, but didn't keep in the end. Either because of how little variance they explained, or because I felt it was already too complicated. I know it's still steep, but I really tried to simplify as much as I could.

# %% [markdown]
# ### #4 : Team recent form through winrate difference

# %% [markdown]
# Theory : Some games are expected to be close, some aren't. This has a tremendous impact on odds distribution. On one hand, the favorite will have odds around 1 and the other around 3, 10, sometimes 50+. On the other hand, if both teams get assigned odds around 2 or 3, indicating a close game, there might be very little leeway for our strategy to work, because of the little variance allowed to us.
#
# What if we could spot games between unbalanced teams, and check if our condition applies to those more or not ?
# For that, we will compute teams' last 5 games' results, translate it into a score (+3 for a win, -3 for a loss). And then compute the difference between the Home team score and the Away team score. This will give us a feature, ranging from -30 to +30, with -30s being unbalanced game in favor of the away team, +30s for the home team, and ~0s for close games.
#
# Let's see where it leads us !

# %%
def away_team_last_5_wr(df):

    last_5_wr = []

    # Dictionary to track the last 5 games of each team
    team_history = {}

    for _, row in df.iterrows():
        away_team = row['away_team']
        result = row['result']

        # Initialize team history if not present
        if away_team not in team_history:
            team_history[away_team] = []

        # Calculate score for the last 5 games
        recent_results = team_history[away_team]
        if len(recent_results) > 0:
            wr = 3*sum(recent_results)
            
        else:
            wr = 0
        last_5_wr.append(wr)

        if len(recent_results) == 5:
            recent_results.pop(0)  
        recent_results.append(result)

    return pd.Series(last_5_wr, name='away_last_5_wr')

Last_5_A_WR = away_team_last_5_wr(Closing_Odds)

# %%
def home_team_last_5_wr(df):

    last_5_wr = []

    # Dictionary to track the last 5 games of each home team
    team_history = {}

    for _, row in df.iterrows():
        home_team = row['home_team']
        result = row['result']

        # Initialize team history if not present
        if home_team not in team_history:
            team_history[home_team] = []

        # Calculate score for the last 5 games
        recent_results = team_history[home_team]
        if len(recent_results) > 0:
            wr = 3*sum(recent_results)

            
        else:
            wr = 0
        last_5_wr.append(wr)

        # Update the team's history with the current game result
        if len(recent_results) == 5:
            recent_results.pop(0)  # Remove the oldest result
        recent_results.append(result)

    return pd.Series(last_5_wr, name='home_last_5_wr')

Last_5_H_WR = home_team_last_5_wr(Closing_Odds)

# %%
Score_Feature = Last_5_H_WR-Last_5_A_WR
Score_Feature

# %%
Closing_Odds['score_feature']=Score_Feature

# %%
X = list(sorted(Closing_Odds['score_feature'].unique()))
Y = Closing_Odds.groupby('score_feature')['condition'].describe()["count"]
Y2 = Closing_Odds[Closing_Odds['condition']==True].groupby('score_feature')['condition'].describe()["count"]

ratios = (Y2 / Y) * 100

fig, axes = pl.subplots(1, 2, figsize=(12, 6))

axes[0].bar(x=X, height=Y, width=2, align='center')
axes[0].bar(x=X, height=Y2, width=1.5, align='center')
axes[0].set_title("Games per difference in recent form (Score)")


axes[1].bar(x=X, height=ratios, width=2, color='grey', align='center')
axes[1].set_title("% of 'good' games per Score difference")


pl.tight_layout()
pl.show()

# %% [markdown]
# Unfortunately, our condition isn't tied at all to our metric. Our hypothesis is rejected.

# %% [markdown]
# ### #5 : Teams' last 5 performances (odds estimators)

# %%
# mznote: this looks interesting - reproducing to get outputs

# %% [markdown]
# Most of our betting strategy revolves around the available odds. Unfortunately, we can't access future games' odds, because of how time works.
#
# Instead, we could try to estimate bookmakers' future odds based on what they did recently for each Home/Away teams.

# %% [markdown]
# Let's do an example first. Here are Marseille's last 5 recorded away games, with their opponent and the associated odds for their win.
# Based on this data, what if we estimate their last away game average odd to be the average of the 5 previous ones ? Would we be off the mark ? Way off ? Or somewhat close ? Let's do it by hand this time.

# %%
Closing_Odds = Closing_Odds.sort_values(by=['match_id'])

# %%
Closing_Odds[Closing_Odds["away_team"]=="Marseille"][["home_team","away_team","match_date","avg_odds_away_win"]].tail(6)
# Out:
#        home_team  away_team  match_date  avg_odds_away_win
# 459338      Lens  Marseille  2015-03-22             1.6348
# 460190     Nimes  Marseille  2015-03-27             1.9000
# 464287  Bordeaux  Marseille  2015-04-12             2.6990
# 465248    Nantes  Marseille  2015-04-17             1.9169
# 469083      Metz  Marseille  2015-05-01             1.7328
# 472779     Lille  Marseille  2015-05-16             2.1545

# %%
Closing_Odds[Closing_Odds["away_team"]=="Marseille"][["home_team","away_team","match_date","avg_odds_away_win"]].tail(6)[:5]
# Out:
#        home_team  away_team  match_date  avg_odds_away_win
# 459338      Lens  Marseille  2015-03-22             1.6348
# 460190     Nimes  Marseille  2015-03-27             1.9000
# 464287  Bordeaux  Marseille  2015-04-12             2.6990
# 465248    Nantes  Marseille  2015-04-17             1.9169
# 469083      Metz  Marseille  2015-05-01             1.7328

# %%
Closing_Odds[Closing_Odds["away_team"]=="Marseille"][["home_team","away_team","match_date","avg_odds_away_win"]].tail(6)[:5]['avg_odds_away_win'].mean()
# Out:
# 1.9767

# %% [markdown]
# Not too bad. It also relies heavily on the opponent, as one could've guessed. Maybe we will have to include that in the future.

# %%
def away_team_last_5_odds(df):

    last_5_odds = []

    # Dictionary to track the last 5 games of each team (away only)
    team_history = {}

    for _, row in df.iterrows():
        away_team = row['away_team']
        odd = row['avg_odds_away_win']

        # Initialize team history if not present
        if away_team not in team_history:
            team_history[away_team] = []

        # Calculate win rate for the last 5 games
        recent_odds = team_history[away_team]

        if len(recent_odds) > 0:
            avg_odds = sum(recent_odds)/len(recent_odds)
            
        else:
            avg_odds = 0
        last_5_odds.append(avg_odds)

        # Update the team's history with the current game result
        if len(recent_odds) == 5:
            recent_odds.pop(0)  # Remove the oldest result
        recent_odds.append(odd)

    return pd.Series(last_5_odds, name='away_last_5_odds')

Last_5_A_Odds = away_team_last_5_odds(Closing_Odds)

# %%
Closing_Odds['avg_away_win_est'] = Last_5_A_Odds
Closing_Odds['avg_away_win_est'].describe()
# Out:
# count    479440.000000
# mean          3.870288
# std           1.933624
# min           0.000000
# 25%           2.744600
# 50%           3.536780
# 75%           4.581405
# max         101.000000
# Name: avg_away_win_est, dtype: float64

# %%
Closing_Odds['avg_away_win_est_mw5'] = Closing_Odds.sort_values(["match_date", "match_id"]).groupby("away_team")["avg_odds_away_win"].transform(lambda x: x.rolling(5, 1, closed="left").mean())

# %%
Closing_Odds.loc[Closing_Odds.away_team=="Marseille", ["home_team","away_team","match_date","avg_odds_away_win", "avg_away_win_est", "avg_away_win_est_mw5"]]
# Out:
#                  home_team  away_team  match_date  avg_odds_away_win  avg_away_win_est  avg_away_win_est_mw5
# 340                  Lille  Marseille  2005-01-11             3.4222           0.00000                   NaN
# 689                   Metz  Marseille  2005-01-22             2.5200           3.42220               3.42220
# 986               Toulouse  Marseille  2005-01-29             2.7950           2.97110               2.97110
# 1923                Bastia  Marseille  2005-02-19             2.2770           2.91240               2.91240
# 2768            St Etienne  Marseille  2005-03-06             2.8800           2.75355               2.75355
# 3699                Monaco  Marseille  2005-03-20             3.6664           2.77884               2.77884
# 4800            Strasbourg  Marseille  2005-04-09             2.8260           2.82768               2.82768
# 5923                Nantes  Marseille  2005-04-23             2.9170           2.88888               2.88888
# 7368               Auxerre  Marseille  2005-05-14             3.2044           2.91328               2.91328
# 8206              Bordeaux  Marseille  2005-05-28             3.1310           3.09876               3.09876
# 9575            Young Boys  Marseille  2005-07-16             2.1988           3.14896               3.14896
# 9885                 Lazio  Marseille  2005-07-27             3.2488           2.85544               2.85544
# 10253                 Lens  Marseille  2005-08-06             3.2050           2.94000               2.94000
# 10519       Dep. La Coruna  Marseille  2005-08-09             4.7129           2.99760               2.99760
# 11198               Rennes  Marseille  2005-08-20             2.8745           3.29930               3.29930
# 12921              Sochaux  Marseille  2005-09-11             2.9508           3.24800               3.24800
# 13164            Beerschot  Marseille  2005-09-15             1.7973           3.39840               3.39840
# 13828             Toulouse  Marseille  2005-09-21             2.5858           3.10810               3.10810
# 14978                 Nice  Marseille  2005-10-02             2.8464           2.98426               2.98426
# 16141          CSKA Moscow  Marseille  2005-10-20             3.8733           2.61096               2.61096
# 16538           St Etienne  Marseille  2005-10-23             3.2217           2.81072               2.81072
# 16792             Bordeaux  Marseille  2005-10-26             3.4200           2.86490               2.86490
# 17615              Le Mans  Marseille  2005-11-05             2.8333           3.18944               3.18944
# 19372               Levski  Marseille  2005-12-01             3.2600           3.23894               3.23894
# 19668                Nancy  Marseille  2005-12-04             2.7000           3.32166               3.32166
# 20424           Strasbourg  Marseille  2005-12-17             2.5967           3.08700               3.08700
# 21378                 Lyon  Marseille  2006-01-11             6.6063           2.96200               2.96200
# 21857           AC Ajaccio  Marseille  2006-01-21             2.0770           3.59926               3.59926
# 22716               Troyes  Marseille  2006-02-05             2.5675           3.44800               3.44800
# 23303               Bolton  Marseille  2006-02-15             3.5925           3.30950               3.30950
# 23591                 Metz  Marseille  2006-02-19             2.1080           3.48800               3.48800
# 24483             Paris SG  Marseille  2006-03-05             5.2318           3.39026               3.39026
# 25184     Zenit Petersburg  Marseille  2006-03-16             3.0370           3.11536               3.11536
# 25527                Lille  Marseille  2006-03-19             3.9833           3.30736               3.30736
# 26561               Nantes  Marseille  2006-04-01             2.7915           3.59052               3.59052
# 27136               Monaco  Marseille  2006-04-08             3.0509           3.43032               3.43032
# 27515                 Lyon  Marseille  2006-04-11             6.2189           3.61890               3.61890
# 29442              Auxerre  Marseille  2006-05-03             3.0109           3.81632               3.81632
# 30161             Bordeaux  Marseille  2006-05-13             2.3842           3.81110               3.81110
# 32215               Dnipro  Marseille  2006-07-22             2.2083           3.49128               3.49128
# 33007                Sedan  Marseille  2006-08-06             2.2610           3.37464               3.37464
# 33233           Young Boys  Marseille  2006-08-10             2.2500           3.21666               3.21666
# 33896              Auxerre  Marseille  2006-08-19             3.0311           2.42288               2.42288
# 35943             Paris SG  Marseille  2006-09-10             3.1345           2.42692               2.42692
# 37030          Montpellier  Marseille  2006-09-20             1.5730           2.57698               2.57698
# 37598               Nantes  Marseille  2006-09-24             1.9822           2.44992               2.44992
# 37840       Mlada Boleslav  Marseille  2006-09-28             2.0273           2.39416               2.39416
# 39343                 Lens  Marseille  2006-10-15             2.9388           2.34962               2.34962
# 40286           St Etienne  Marseille  2006-10-25             2.4811           2.33116               2.33116
# 40825                 Nice  Marseille  2006-10-29             2.3125           2.20048               2.20048
# 42199                Lille  Marseille  2006-11-12             3.8473           2.34838               2.34838
# 43074               Troyes  Marseille  2006-11-25             2.2731           2.72140               2.72140
# 43816              Sochaux  Marseille  2006-12-03             3.0300           2.77056               2.77056
# 44536                Nancy  Marseille  2006-12-16             3.0362           2.78880               2.78880
# 45357              Cambrai  Marseille  2007-01-06             1.1180           2.89982               2.89982
# 45661               Rennes  Marseille  2007-01-14             2.9685           2.66092               2.66092
# 45894              Le Mans  Marseille  2007-01-20             2.5987           2.48516               2.48516
# 46220              Le Mans  Marseille  2007-01-27             2.5757           2.55028               2.55028
# 47136             Bordeaux  Marseille  2007-02-11             3.1454           2.45942               2.45942
# 47912             Toulouse  Marseille  2007-02-24             2.6625           2.48126               2.48126
# 49207                 Lyon  Marseille  2007-03-11             5.8800           2.79016               2.79016
# 50562              Lorient  Marseille  2007-03-31             2.5267           3.37246               3.37246
# 51940         Valenciennes  Marseille  2007-04-14             2.4456           3.35806               3.35806
# 54264               Monaco  Marseille  2007-05-06             2.6920           3.33204               3.33204
# 55274           St Etienne  Marseille  2007-05-19             2.3000           3.24136               3.24136
# 58009           Strasbourg  Marseille  2007-08-04             2.0962           3.16886               3.16886
# 58971         Valenciennes  Marseille  2007-08-15             2.3136           2.41210               2.41210
# 59807                 Caen  Marseille  2007-08-25             2.3138           2.36948               2.36948
# 60805             Paris SG  Marseille  2007-09-02             3.1800           2.34312               2.34312
# 62422              Auxerre  Marseille  2007-09-22             2.8518           2.44072               2.44072
# 63842            Liverpool  Marseille  2007-10-03            10.5159           2.55108               2.55108
# 64084           St Etienne  Marseille  2007-10-06             3.2100           4.23502               4.23502
# 65864              Sochaux  Marseille  2007-10-27             2.8495           4.41430               4.41430
# 67123             FC Porto  Marseille  2007-11-06             5.6241           4.52144               4.52144
# 67625                 Lyon  Marseille  2007-11-11             6.8990           5.01026               5.01026
# 68660             Besiktas  Marseille  2007-11-28             2.6450           5.81970               5.81970
# 68832                Lille  Marseille  2007-12-01             3.0627           4.24552               4.24552
# 69936             Bordeaux  Marseille  2007-12-16             3.5409           4.21606               4.21606
# 70705             Beauvais  Marseille  2008-01-05             1.3690           4.35434               4.35434
# 71047               Rennes  Marseille  2008-01-13             2.8964           3.50332               3.50332
# 71178              Auxerre  Marseille  2008-01-16             2.8595           2.70280               2.70280
# 71552                Nancy  Marseille  2008-01-23             3.2124           2.74570               2.74570
# 72668                 Nice  Marseille  2008-02-10             2.5047           2.77564               2.77564
# 73303       Spartak Moscow  Marseille  2008-02-21             4.0762           2.56840               2.56840
# 73634             Toulouse  Marseille  2008-02-24             2.4700           3.10984               3.10984
# 75041     Zenit Petersburg  Marseille  2008-03-12             4.7370           3.02456               3.02456
# 75475                 Lens  Marseille  2008-03-16             2.9567           3.40006               3.40006
# 75687            Carquefou  Marseille  2008-03-19             1.1932           3.34892               3.34892
# 76957              Lorient  Marseille  2008-03-30             2.6843           3.08662               3.08662
# 78241                 Metz  Marseille  2008-04-12             1.6638           2.80824               2.80824
# 80017               Monaco  Marseille  2008-04-27             2.2209           2.64700               2.64700
# 81192              Le Mans  Marseille  2008-05-10             2.1728           2.14378               2.14378
# 85290               Rennes  Marseille  2008-08-09             2.6531           1.98700               1.98700
# 85729                Brann  Marseille  2008-08-13             1.8321           2.27898               2.27898
# 86642             Le Havre  Marseille  2008-08-23             2.0873           2.10854               2.10854
# 88597             Bordeaux  Marseille  2008-09-13             3.2157           2.19324               2.19324
# 90066              Sochaux  Marseille  2008-09-24             2.2104           2.39220               2.39220
# 90405              Le Mans  Marseille  2008-09-27             2.3809           2.39972               2.39972
# 90984          Atl. Madrid  Marseille  2008-10-01             5.2733           2.34528               2.34528
# 92900         Valenciennes  Marseille  2008-10-19             2.1467           3.03352               3.03352
# 93234                  PSV  Marseille  2008-10-22             2.7938           3.04540               3.04540
# 94302               Nantes  Marseille  2008-10-29             2.1454           2.96102               2.96102
# 95614             Grenoble  Marseille  2008-11-08             2.0133           2.94802               2.94802
# 97907            Liverpool  Marseille  2008-11-26             8.0172           2.87450               2.87450
# 98384             Toulouse  Marseille  2008-11-30             2.3032           3.42328               3.42328
# 99574                 Lyon  Marseille  2008-12-14             4.6538           3.45458               3.45458
# 100816             Auxerre  Marseille  2009-01-10             2.1429           3.82658               3.82658
# 102234                Lyon  Marseille  2009-01-28             3.8683           3.82608               3.82608
# 102560             Sochaux  Marseille  2009-02-01             2.2877           4.19708               4.19708
# 103682              Monaco  Marseille  2009-02-15             2.2673           3.05118               3.05118
# 104679              Twente  Marseille  2009-02-26             2.6523           3.04400               3.04400
# 105117                Caen  Marseille  2009-03-01             2.1896           2.64370               2.64370
# 106945            Paris SG  Marseille  2009-03-15             3.3408           2.65304               2.65304
# 107314                Ajax  Marseille  2009-03-18             2.8481           2.54754               2.54754
# 109566          St Etienne  Marseille  2009-04-05             2.2864           2.65962               2.65962
# 110048            Shakhtar  Marseille  2009-04-09             3.8231           2.66344               2.66344
# 111711             Lorient  Marseille  2009-04-19             2.0296           2.89760               2.89760
# 112833               Lille  Marseille  2009-04-26             2.9807           2.86560               2.86560
# 115375                Nice  Marseille  2009-05-13             1.6446           2.79358               2.79358
# 116671               Nancy  Marseille  2009-05-23             1.6024           2.55288               2.55288
# 120899            Bordeaux  Marseille  2009-07-21             2.4680           2.41608               2.41608
# 121943                Lens  Marseille  2009-08-01             2.1216           2.14506               2.14506
# 122644            Grenoble  Marseille  2009-08-08             1.7277           2.16346               2.16346
# 124792              Rennes  Marseille  2009-08-22             2.3281           1.91286               1.91286
# 128036             Le Mans  Marseille  2009-09-12             1.8212           2.04956               2.04956
# 130770        Valenciennes  Marseille  2009-09-26             1.7481           2.09332               2.09332
# 131665         Real Madrid  Marseille  2009-09-30            11.1620           1.94934               1.94934
# 134050               Nancy  Marseille  2009-10-17             1.9596           3.75742               3.75742
# 134829              Zurich  Marseille  2009-10-21             1.7785           3.80380               3.80380
# 138064                Lyon  Marseille  2009-11-08             3.5078           3.69388               3.69388
# 138579       Arles-Avignon  Marseille  2009-11-13             1.7700           4.03120               4.03120
# 140062            AC Milan  Marseille  2009-11-25             3.9146           4.03558               4.03558
# 140338                Lens  Marseille  2009-11-28             1.8874           2.58610               2.58610
# 141280                Nice  Marseille  2009-12-05             2.0656           2.57166               2.57166
# 142683             Lorient  Marseille  2009-12-16             2.2780           2.62908               2.62908
# 142820          St Etienne  Marseille  2009-12-19             1.8125           2.38312               2.38312
# 143870           Trelissac  Marseille  2010-01-10             1.1823           2.39162               2.39162
# 144088          St Etienne  Marseille  2010-01-13             1.9336           1.84516               1.84516
# 144465            Bordeaux  Marseille  2010-01-17             4.0216           1.85440               1.85440
# 145915         Montpellier  Marseille  2010-01-30             2.2015           2.24560               2.24560
# 146458            Toulouse  Marseille  2010-02-03             2.5864           2.23030               2.23030
# 147391                Lens  Marseille  2010-02-10             2.1043           2.38508               2.38508
# 147704              Monaco  Marseille  2010-02-13             2.2331           2.56948               2.56948
# 148273       FC Copenhagen  Marseille  2010-02-18             2.3533           2.62938               2.62938
# 149595            Paris SG  Marseille  2010-02-28             2.3844           2.29572               2.29572
# 151143             Benfica  Marseille  2010-03-11             4.0304           2.33230               2.33230
# 151721            Toulouse  Marseille  2010-03-14             2.2011           2.62110               2.62110
# 157457             Sochaux  Marseille  2010-04-14             1.6144           2.64046               2.64046
# 157987            Boulogne  Marseille  2010-04-17             1.4222           2.51672               2.51672
# 160314             Auxerre  Marseille  2010-04-30             2.4508           2.33050               2.33050
# 161841               Lille  Marseille  2010-05-08             5.2011           2.34378               2.34378
# 166968              Vannes  Marseille  2010-07-09             1.4608           2.57792               2.57792
# 167389              Monaco  Marseille  2010-07-16             1.8776           2.42986               2.42986
# 173386          AC Ajaccio  Marseille  2010-09-03             2.1533           2.48250               2.48250
# 177288             Chelsea  Marseille  2010-09-28             8.6730           2.62872               2.62872
# 181279            Guingamp  Marseille  2010-10-27             1.7468           3.87316               3.87316
# 182285              Zilina  Marseille  2010-11-03             1.6769           3.18230               3.18230
# 184951      Spartak Moscow  Marseille  2010-11-23             2.6507           3.22552               3.22552
# 187695            Evian TG  Marseille  2011-01-09             1.8881           3.38014               3.38014
# 188412             Auxerre  Marseille  2011-01-19             2.2667           3.32710               3.32710
# 194698   Manchester United  Marseille  2011-03-15             6.7881           2.04584               2.04584
# 209681              Vannes  Marseille  2011-07-08             1.3904           3.05410               3.05410
# 211922               Lille  Marseille  2011-07-27             2.4744           2.99680               2.99680
# 215202             Auxerre  Marseille  2011-08-14             2.1043           2.96154               2.96154
# 218244               Lille  Marseille  2011-08-28             3.3996           3.00478               3.00478
# 221349  Olympiakos Piraeus  Marseille  2011-09-13             2.8648           3.23136               3.23136
# 222526                Lyon  Marseille  2011-09-18             3.3586           2.44670               2.44670
# 223816        Valenciennes  Marseille  2011-09-24             2.3418           2.84034               2.84034
# 228152            Toulouse  Marseille  2011-10-15             2.5654           2.81382               2.81382
# 231416               Dijon  Marseille  2011-10-29             1.8307           2.90604               2.90604
# 232314             Arsenal  Marseille  2011-11-01             5.0661           2.59226               2.59226
# 235160         Montpellier  Marseille  2011-11-19             2.5064           3.03252               3.03252
# 237439                Caen  Marseille  2011-12-02             2.0168           2.86208               2.86208
# 238353            Dortmund  Marseille  2011-12-06             5.0626           2.79708               2.79708
# 240116               Nancy  Marseille  2011-12-20             1.9419           3.29652               3.29652
# 241238            Red Star  Marseille  2012-01-07             1.3327           3.31876               3.31876
# 241614                Caen  Marseille  2012-01-10             1.8296           2.57208               2.57208
# 244210              Rennes  Marseille  2012-01-29             2.6675           2.43672               2.43672
# 248563               Brest  Marseille  2012-02-26             2.0196           2.56686               2.56686
# 250400            Evian TG  Marseille  2012-03-06             2.2554           1.95826               1.95826
# 250702          AC Ajaccio  Marseille  2012-03-09             1.9196           2.02096               2.02096
# 251888               Inter  Marseille  2012-03-13             3.8907           2.13834               2.13834
# 253473            Quevilly  Marseille  2012-03-20             1.3175           2.55056               2.55056
# 254197                Nice  Marseille  2012-03-24             2.3089           2.28056               2.28056
# 256764       Bayern Munich  Marseille  2012-04-03             8.6600           2.33842               2.33842
# 257888            Paris SG  Marseille  2012-04-08             4.6811           3.61934               3.61934
# 259140                Lyon  Marseille  2012-04-14             2.7771           4.17164               4.17164
# 260749            Bordeaux  Marseille  2012-04-21             3.1333           3.94892               3.94892
# 262000             Lorient  Marseille  2012-04-27             2.9059           4.31208               4.31208
# 264846          St Etienne  Marseille  2012-05-07             3.2252           4.43148               4.43148
# 267228             Sochaux  Marseille  2012-05-20             3.3796           3.34452               3.34452
# 271922                Sion  Marseille  2012-07-08             2.2138           3.08422               3.08422
# 272962               Nimes  Marseille  2012-07-20             1.8658           2.97156               2.97156
# 273633                Thun  Marseille  2012-07-25             1.7658           2.71806               2.71806
# 274109            Evian TG  Marseille  2012-07-28             2.2115           2.49004               2.49004
# 274687       Eskisehirspor  Marseille  2012-08-02             2.0408           2.28730               2.28730
# 276768               Reims  Marseille  2012-08-12             2.1760           2.01954               2.01954
# 279033    Sheriff Tiraspol  Marseille  2012-08-23             1.6161           2.01198               2.01198
# 279978         Montpellier  Marseille  2012-08-26             3.1477           1.96204               1.96204
# 284781               Nancy  Marseille  2012-09-16             2.1244           2.23842               2.23842
# 285554          Fenerbahce  Marseille  2012-09-20             2.7881           2.22100               2.22100
# 288658        Valenciennes  Marseille  2012-09-30             2.2700           2.37046               2.37046
# 293349              Troyes  Marseille  2012-10-21             1.6200           2.38926               2.38926
# 294184  B. Monchengladbach  Marseille  2012-10-25             2.8952           2.39004               2.39004
# 295784            Paris SG  Marseille  2012-10-31             4.4739           2.33954               2.33954
# 296841          AC Ajaccio  Marseille  2012-11-04             2.2404           2.80944               2.80944
# 299860            Bordeaux  Marseille  2012-11-18             3.3846           2.69990               2.69990
# 302535               Brest  Marseille  2012-12-02             2.2579           2.92282               2.92282
# 303010        AEL Limassol  Marseille  2012-12-06             2.2596           3.05040               3.05040
# 303810              Bastia  Marseille  2012-12-12             2.0774           2.92328               2.92328
# 304072            Toulouse  Marseille  2012-12-15             2.8129           2.44398               2.44398
# 306743             Sochaux  Marseille  2013-01-13             1.8096           2.55848               2.55848
# 308284              Rennes  Marseille  2013-01-26             2.7064           2.24348               2.24348
# 308908               Rouen  Marseille  2013-01-30             1.6004           2.33318               2.33318
# 310817            Evian TG  Marseille  2013-02-10             2.1396           2.20134               2.20134
# 313316            Paris SG  Marseille  2013-02-24             6.5264           2.21378               2.21378
# 313851            Paris SG  Marseille  2013-02-27             5.1274           2.95648               2.95648
# 316354                Lyon  Marseille  2013-03-10             3.3832           3.62004               3.62004
# 320647                Nice  Marseille  2013-03-31             2.5204           3.75540               3.75540
# 324341               Lille  Marseille  2013-04-14             4.0363           3.93940               3.93940
# 327823             Lorient  Marseille  2013-04-27             2.6929           4.31874               4.31874
# 333202          St Etienne  Marseille  2013-05-18             4.1496           3.55204               3.55204
# 339549                Sion  Marseille  2013-07-09             1.5962           3.35648               3.35648
# 341510                Lens  Marseille  2013-07-24             1.8188           2.99908               2.99908
# 342352           Wolfsburg  Marseille  2013-07-28             3.2152           2.85876               2.85876
# 342620               Parma  Marseille  2013-07-31             2.7008           2.69454               2.69454
# 343269           Sampdoria  Marseille  2013-08-03             2.8372           2.69612               2.69612
# 344875            Guingamp  Marseille  2013-08-11             2.2718           2.43364               2.43364
# 347609        Valenciennes  Marseille  2013-08-24             2.1268           2.56876               2.56876
# 352482            Toulouse  Marseille  2013-09-14             2.5848           2.63036               2.63036
# 354409              Bastia  Marseille  2013-09-21             2.2438           2.50428               2.50428
# 356500             Lorient  Marseille  2013-09-28             2.7124           2.41288               2.41288
# 357633            Dortmund  Marseille  2013-10-01             9.5222           2.38792               2.38792
# 361024                Nice  Marseille  2013-10-18             2.6259           3.83800               3.83800
# 365023              Rennes  Marseille  2013-11-02             2.8031           3.93782               3.93782
# 366165              Napoli  Marseille  2013-11-06             8.6727           3.98148               3.98148
# 368796          AC Ajaccio  Marseille  2013-11-22             1.8907           5.26726               5.26726
# 369958             Arsenal  Marseille  2013-11-26            12.2474           5.10292               5.10292
# 371292               Lille  Marseille  2013-12-03             3.8293           5.64796               5.64796
# 373065                Lyon  Marseille  2013-12-15             3.3966           5.88864               5.88864
# 375720            Evian TG  Marseille  2014-01-12             2.1668           6.00734               6.00734
# 376079                Lyon  Marseille  2014-01-15             3.4477           4.70616               4.70616
# 377805              Monaco  Marseille  2014-01-26             4.4954           5.01756               5.01756
# 381631          St Etienne  Marseille  2014-02-16             3.6685           3.46716               3.46716
# 384523            Paris SG  Marseille  2014-03-02             9.4497           3.43500               3.43500
# 386923               Reims  Marseille  2014-03-14             2.2814           4.64562               4.64562
# 390897             Sochaux  Marseille  2014-03-29             2.3086           4.66854               4.66854
# 393972         Montpellier  Marseille  2014-04-11             3.0329           4.44072               4.44072
# 397535              Nantes  Marseille  2014-04-25             2.2479           4.14822               4.14822
# 401212            Bordeaux  Marseille  2014-05-10             2.3926           3.86410               3.86410
# 409549    Bayer Leverkusen  Marseille  2014-07-19             3.6400           2.45268               2.45268
# 411058                Bari  Marseille  2014-07-30             1.5619           2.72440               2.72440
# 412796              Bastia  Marseille  2014-08-09             2.0281           2.57506               2.57506
# 416406            Guingamp  Marseille  2014-08-23             2.6364           2.37410               2.37410
# 421905            Evian TG  Marseille  2014-09-14             1.9224           2.45180               2.45180
# 424344               Reims  Marseille  2014-09-23             1.9582           2.35776               2.35776
# 427212                Caen  Marseille  2014-10-04             2.0676           2.02140               2.02140
# 432718                Lyon  Marseille  2014-10-26             2.7425           2.12254               2.12254
# 433497              Rennes  Marseille  2014-10-29             2.1614           2.26542               2.26542
# 436282            Paris SG  Marseille  2014-11-09             5.2752           2.17042               2.17042
# 437084            Espanyol  Marseille  2014-11-14             2.8100           2.84098               2.84098
# 440750             Lorient  Marseille  2014-12-02             2.1054           3.01134               3.01134
# 442774              Monaco  Marseille  2014-12-14             3.0645           3.01890               3.01890
# 444795            Grenoble  Marseille  2015-01-04             1.1804           3.08330               3.08330
# 445153         Montpellier  Marseille  2015-01-09             1.9954           2.88710               2.88710
# 446981                Nice  Marseille  2015-01-23             2.2164           2.23114               2.23114
# 449416              Rennes  Marseille  2015-02-07             2.2079           2.11242               2.11242
# 452390          St Etienne  Marseille  2015-02-22             3.1332           2.13292               2.13292
# 454712            Toulouse  Marseille  2015-03-06             2.3272           2.14666               2.14666
# 459338                Lens  Marseille  2015-03-22             1.6348           2.37602               2.37602
# 460190               Nimes  Marseille  2015-03-27             1.9000           2.30390               2.30390
# 464287            Bordeaux  Marseille  2015-04-12             2.6990           2.24062               2.24062
# 465248              Nantes  Marseille  2015-04-17             1.9169           2.33884               2.33884
# 469083                Metz  Marseille  2015-05-01             1.7328           2.09558               2.09558
# 472779               Lille  Marseille  2015-05-16             2.1545           1.97670               1.97670

# %%
def home_team_last_5_odds(df):

    last_5_odds = []

    # Dictionary to track the last 5 games of each team (home only)
    team_history = {}

    for _, row in df.iterrows():
        home_team = row['home_team']
        odd = row['avg_odds_home_win']

        # Initialize team history if not present
        if home_team not in team_history:
            team_history[home_team] = []

        # Calculate win rate for the last 5 games
        recent_odds = team_history[home_team]

        if len(recent_odds) > 0:
            avg_odds = sum(recent_odds)/len(recent_odds)
            
        else:
            avg_odds = 0
        last_5_odds.append(avg_odds)

        # Update the team's history with the current game result
        if len(recent_odds) == 5:
            recent_odds.pop(0)  # Remove the oldest result
        recent_odds.append(odd)

    return pd.Series(last_5_odds, name='home_last_5_odds')

Last_5_H_Odds = home_team_last_5_odds(Closing_Odds)

# %%
Closing_Odds['avg_home_win_est'] = Last_5_H_Odds
Closing_Odds['avg_home_win_est'].describe()
# Out:
# count    479440.000000
# mean          2.429491
# std           1.290784
# min           0.000000
# 25%           1.838100
# 50%           2.196340
# 75%           2.693725
# max          61.000000
# Name: avg_home_win_est, dtype: float64

# %%
Closing_Odds['avg_home_win_est_mw5'] = Closing_Odds.sort_values(["match_date", "match_id"]).groupby("home_team")["avg_odds_home_win"].transform(lambda x: x.rolling(5, 1, closed="left").mean())

# %%
Closing_Odds.loc[Closing_Odds.home_team=="Marseille", ["home_team","away_team","match_date","avg_odds_home_win", "avg_home_win_est", "avg_home_win_est_mw5"]]
# Out:
#         home_team           away_team  match_date  avg_odds_home_win  avg_home_win_est  avg_home_win_est_mw5
# 231     Marseille              Angers  2005-01-08             1.1988           0.00000                   NaN
# 505     Marseille                Nice  2005-01-16             1.6930           1.19880               1.19880
# 861     Marseille             Sochaux  2005-01-25             1.6610           1.44590               1.44590
# 1311    Marseille              Rennes  2005-02-05             1.5510           1.51760               1.51760
# 2406    Marseille              Istres  2005-02-27             1.3620           1.52595               1.52595
# 3044    Marseille                Lens  2005-03-12             1.7320           1.49316               1.49316
# 4491    Marseille            Paris SG  2005-04-03             1.7818           1.59980               1.59980
# 5320    Marseille          AC Ajaccio  2005-04-16             1.4809           1.61756               1.61756
# 6918    Marseille                Caen  2005-05-07             1.4300           1.58154               1.58154
# 7835    Marseille                Lyon  2005-05-21             2.2913           1.55734               1.55734
# 9756    Marseille          Young Boys  2005-07-23             1.3683           1.74320               1.74320
# 9964    Marseille            Bordeaux  2005-07-30             1.7050           1.67046               1.67046
# 10125   Marseille               Lazio  2005-08-03             1.8825           1.65510               1.65510
# 10896   Marseille                Lyon  2005-08-14             2.9364           1.73542               1.73542
# 11521   Marseille      Dep. La Coruna  2005-08-23             2.2033           2.03670               2.03670
# 11776   Marseille          AC Ajaccio  2005-08-27             1.6250           2.01910               2.01910
# 13553   Marseille              Troyes  2005-09-18             1.6318           2.07044               2.07044
# 14074   Marseille                Metz  2005-09-24             1.5300           2.05580               2.05580
# 14606   Marseille           Beerschot  2005-09-29             1.2230           1.98530               1.98530
# 15868   Marseille            Paris SG  2005-10-16             2.2927           1.64262               1.64262
# 17021   Marseille               Lille  2005-10-29             1.8927           1.66050               1.66050
# 18455   Marseille              Nantes  2005-11-19             1.7220           1.71404               1.71404
# 18896   Marseille          Heerenveen  2005-11-24             1.3950           1.73208               1.73208
# 19177   Marseille              Monaco  2005-11-27             2.2125           1.70508               1.70508
# 19991   Marseille             Auxerre  2005-12-10             2.0227           1.90298               1.90298
# 20291   Marseille      Din. Bucuresti  2005-12-14             2.0590           1.84898               1.84898
# 21097   Marseille                Lens  2006-01-04             1.9844           1.88224               1.88224
# 21259   Marseille            Le Havre  2006-01-08             1.3413           1.93472               1.93472
# 21594   Marseille              Rennes  2006-01-15             1.6800           1.92398               1.92398
# 22211   Marseille             Sochaux  2006-01-28             1.6031           1.81748               1.81748
# 22459   Marseille                Metz  2006-02-01             1.4040           1.73356               1.73356
# 23135   Marseille            Toulouse  2006-02-12             1.7013           1.60256               1.60256
# 23766   Marseille              Bolton  2006-02-23             1.9900           1.54594               1.54594
# 24049   Marseille                Nice  2006-02-26             1.8700           1.67568               1.67568
# 24654   Marseille    Zenit Petersburg  2006-03-09             1.6780           1.71368               1.71368
# 24991   Marseille          St Etienne  2006-03-12             1.8533           1.72866               1.72866
# 25728   Marseille             Sochaux  2006-03-22             1.5975           1.81852               1.81852
# 25939   Marseille             Le Mans  2006-03-25             1.6864           1.79776               1.79776
# 27810   Marseille               Nancy  2006-04-15             1.6018           1.73704               1.73704
# 28289   Marseille              Rennes  2006-04-20             1.7944           1.68340               1.68340
# 29028   Marseille            Paris SG  2006-04-29             2.5875           1.70668               1.70668
# 29656   Marseille          Strasbourg  2006-05-06             1.2269           1.85352               1.85352
# 32037   Marseille              Dnipro  2006-07-15             1.4082           1.77940               1.77940
# 33567   Marseille              Rennes  2006-08-13             1.6200           1.72376               1.72376
# 34439   Marseille          Young Boys  2006-08-24             1.3427           1.72740               1.72740
# 34830   Marseille             Le Mans  2006-08-27             1.5764           1.63706               1.63706
# 36291   Marseille      Mlada Boleslav  2006-09-14             1.2664           1.43484               1.43484
# 36720   Marseille            Bordeaux  2006-09-17             1.8491           1.44274               1.44274
# 38313   Marseille            Toulouse  2006-10-01             1.5933           1.53092               1.53092
# 40029   Marseille                Lyon  2006-10-22             2.9480           1.52558               1.52558
# 41269   Marseille             Lorient  2006-11-04             1.3658           1.84664               1.84664
# 42732   Marseille        Valenciennes  2006-11-19             1.4642           1.80452               1.80452
# 44126   Marseille              Monaco  2006-12-09             1.8142           1.84408               1.84408
# 44848   Marseille          St Etienne  2006-12-22             1.9000           1.83710               1.83710
# 46100   Marseille             Auxerre  2007-01-24             1.6800           1.89844               1.89844
# 46506   Marseille                Lyon  2007-01-31             2.9792           1.64484               1.64484
# 46767   Marseille            Paris SG  2007-02-04             1.8146           1.96752               1.96752
# 47566   Marseille              Nantes  2007-02-18             1.4986           2.03760               2.03760
# 48224   Marseille              Vannes  2007-02-27             1.1700           1.97448               1.97448
# 48623   Marseille                Lens  2007-03-04             2.1915           1.82848               1.82848
# 49641   Marseille                Nice  2007-03-17             1.7131           1.93078               1.93078
# 51474   Marseille               Lille  2007-04-08             2.0050           1.67756               1.67756
# 52418   Marseille              Nantes  2007-04-18             1.5677           1.71564               1.71564
# 52670   Marseille              Troyes  2007-04-21             1.4471           1.72946               1.72946
# 53625   Marseille             Sochaux  2007-04-29             1.6869           1.78488               1.78488
# 54457   Marseille               Nancy  2007-05-09             1.3893           1.68396               1.68396
# 54672   Marseille             Sochaux  2007-05-12             2.0173           1.61920               1.61920
# 55840   Marseille               Sedan  2007-05-26             1.3420           1.62166               1.62166
# 58582   Marseille              Rennes  2007-08-11             1.5879           1.57652               1.57652
# 59431   Marseille               Nancy  2007-08-19             1.7036           1.60468               1.60468
# 60318   Marseille                Nice  2007-08-29             1.5606           1.60802               1.60802
# 61657   Marseille            Toulouse  2007-09-15             1.7076           1.64228               1.64228
# 62099   Marseille            Besiktas  2007-09-18             1.8856           1.58034               1.58034
# 65384   Marseille                Lens  2007-10-21             1.9195           1.68906               1.68906
# 65597   Marseille            FC Porto  2007-10-24             2.5271           1.75538               1.75538
# 66299   Marseille                Metz  2007-10-30             1.5567           1.92008               1.92008
# 66684   Marseille             Lorient  2007-11-03             1.7162           1.91930               1.91930
# 68268   Marseille                Metz  2007-11-24             1.5024           1.92102               1.92102
# 69365   Marseille              Monaco  2007-12-08             2.1114           1.84438               1.84438
# 69630   Marseille           Liverpool  2007-12-11             4.0518           1.88276               1.88276
# 70158   Marseille             Le Mans  2007-12-22             1.8224           2.18770               2.18770
# 71312   Marseille        Valenciennes  2008-01-19             1.7190           2.24084               2.24084
# 71686   Marseille                Caen  2008-01-26             1.7184           2.24140               2.24140
# 72224   Marseille              Monaco  2008-02-03             1.8742           2.28460               2.28460
# 72837   Marseille      Spartak Moscow  2008-02-13             1.6168           2.23716               2.23716
# 73142   Marseille            Paris SG  2008-02-17             1.7740           1.75016               1.75016
# 74036   Marseille             Auxerre  2008-03-01             1.6357           1.74048               1.74048
# 74421   Marseille    Zenit Petersburg  2008-03-06             1.5838           1.72382               1.72382
# 74810   Marseille          St Etienne  2008-03-09             1.7014           1.69690               1.69690
# 75993   Marseille             Sochaux  2008-03-22             1.8371           1.66234               1.66234
# 77719   Marseille                Lyon  2008-04-06             2.7450           1.70640               1.70640
# 79282   Marseille               Lille  2008-04-20             1.6759           1.90060               1.90060
# 80707   Marseille            Bordeaux  2008-05-04             2.0648           1.90864               1.90864
# 81851   Marseille          Strasbourg  2008-05-17             1.1888           2.00484               2.00484
# 86224   Marseille             Auxerre  2008-08-17             1.5527           1.90232               1.90232
# 87114   Marseille               Brann  2008-08-27             1.2050           1.84544               1.84544
# 87402   Marseille             Sochaux  2008-08-30             1.4374           1.53744               1.53744
# 89094   Marseille           Liverpool  2008-09-16             3.1922           1.48974               1.48974
# 89709   Marseille              Monaco  2008-09-21             1.5822           1.71522               1.71522
# 91277   Marseille                Caen  2008-10-04             1.4822           1.79390               1.79390
# 93896   Marseille            Paris SG  2008-10-26             1.7383           1.77980               1.77980
# 94691   Marseille          St Etienne  2008-11-01             1.5678           1.88646               1.88646
# 95246   Marseille                 PSV  2008-11-04             1.8280           1.91254               1.91254
# 96561   Marseille             Lorient  2008-11-15             1.3956           1.63970               1.63970
# 97647   Marseille               Lille  2008-11-23             1.8216           1.60238               1.60238
# 98815   Marseille                Nice  2008-12-06             1.7260           1.67026               1.67026
# 99238   Marseille         Atl. Madrid  2008-12-09             2.0496           1.66780               1.66780
# 100124  Marseille               Nancy  2008-12-21             1.4992           1.76416               1.76416
# 101298  Marseille            Le Havre  2009-01-17             1.3125           1.69840               1.69840
# 103089  Marseille            Bordeaux  2009-02-08             2.4231           1.68178               1.68178
# 104012  Marseille              Twente  2009-02-19             1.6142           1.80208               1.80208
# 104387  Marseille             Le Mans  2009-02-22             1.4496           1.77972               1.77972
# 105764  Marseille        Valenciennes  2009-03-07             1.4920           1.65972               1.65972
# 106407  Marseille                Ajax  2009-03-12             1.8242           1.65828               1.65828
# 107664  Marseille              Nantes  2009-03-21             1.4380           1.76062               1.76062
# 110645  Marseille            Grenoble  2009-04-12             1.3384           1.56360               1.56360
# 111086  Marseille            Shakhtar  2009-04-16             1.7881           1.50844               1.50844
# 113590  Marseille            Toulouse  2009-05-02             1.5250           1.57614               1.57614
# 116081  Marseille                Lyon  2009-05-17             2.0552           1.58274               1.58274
# 117495  Marseille              Rennes  2009-05-30             1.4577           1.62894               1.62894
# 120164  Marseille      Din. Bucuresti  2009-07-10             1.7713           1.63288               1.63288
# 120596  Marseille          AC Ajaccio  2009-07-17             1.4071           1.71946               1.71946
# 121276  Marseille            Toulouse  2009-07-25             1.8695           1.64326               1.64326
# 121601  Marseille          St Etienne  2009-07-29             1.7033           1.71216               1.71216
# 123900  Marseille               Lille  2009-08-16             1.6462           1.64178               1.64178
# 126354  Marseille            Bordeaux  2009-08-30             2.1308           1.67948               1.67948
# 128791  Marseille            AC Milan  2009-09-15             2.2427           1.75138               1.75138
# 129300  Marseille         Montpellier  2009-09-19             1.3996           1.91850               1.91850
# 132470  Marseille              Monaco  2009-10-04             1.4722           1.82452               1.82452
# 136585  Marseille            Toulouse  2009-10-31             1.5419           1.77830               1.77830
# 137289  Marseille              Zurich  2009-11-03             1.2877           1.75744               1.75744
# 139244  Marseille            Paris SG  2009-11-20             1.6978           1.58882               1.58882
# 141840  Marseille         Real Madrid  2009-12-08             3.0243           1.47984               1.47984
# 142154  Marseille            Boulogne  2009-12-12             1.2267           1.80478               1.80478
# 143135  Marseille             Auxerre  2009-12-23             1.4432           1.75568               1.75568
# 144816  Marseille             Le Mans  2010-01-20             1.2988           1.73594               1.73594
# 145630  Marseille               Lille  2010-01-27             1.9685           1.73816               1.73816
# 146998  Marseille        Valenciennes  2010-02-07             1.4308           1.79230               1.79230
# 148676  Marseille               Nancy  2010-02-21             1.4278           1.47360               1.47360
# 149108  Marseille       FC Copenhagen  2010-02-25             1.5581           1.51382               1.51382
# 150624  Marseille             Lorient  2010-03-07             1.4104           1.53680               1.53680
# 152274  Marseille             Benfica  2010-03-18             2.0900           1.55912               1.55912
# 152962  Marseille                Lyon  2010-03-21             2.2878           1.58342               1.58342
# 153932  Marseille            Bordeaux  2010-03-27             2.4812           1.75482               1.75482
# 155581  Marseille                Lens  2010-04-04             1.2926           1.96550               1.96550
# 156041  Marseille             Sochaux  2010-04-07             1.3004           1.91240               1.91240
# 156888  Marseille                Nice  2010-04-11             1.2744           1.89040               1.89040
# 159712  Marseille          St Etienne  2010-04-25             1.2456           1.72728               1.72728
# 161417  Marseille              Rennes  2010-05-05             1.3580           1.51884               1.51884
# 163009  Marseille            Grenoble  2010-05-15             1.2389           1.29420               1.29420
# 168093  Marseille             Catania  2010-07-24             1.6936           1.28346               1.28346
# 168408  Marseille            Paris SG  2010-07-28             2.3562           1.36210               1.36210
# 169074  Marseille            Valencia  2010-08-01             2.0530           1.57846               1.57846
# 174995  Marseille      Spartak Moscow  2010-09-15             1.6122           1.73994               1.73994
# 180119  Marseille              Zilina  2010-10-19             1.2563           1.79078               1.79078
# 183318  Marseille              Monaco  2010-11-10             1.6341           1.79426               1.79426
# 186208  Marseille             Chelsea  2010-12-08             2.6712           1.78236               1.78236
# 191959  Marseille   Manchester United  2011-02-23             3.0004           1.84536               1.84536
# 200369  Marseille         Montpellier  2011-04-23             1.8116           2.03484               2.03484
# 210437  Marseille         Montpellier  2011-07-15             1.7400           2.07472               2.07472
# 211099  Marseille               Betis  2011-07-20             1.7533           2.17146               2.17146
# 211591  Marseille             Udinese  2011-07-23             2.0861           2.19530               2.19530
# 212936  Marseille   Manchester United  2011-08-02             1.6289           2.07828               2.07828
# 213446  Marseille             Sochaux  2011-08-06             1.4567           1.80398               1.80398
# 216706  Marseille          St Etienne  2011-08-21             1.5274           1.73300               1.73300
# 220407  Marseille              Rennes  2011-09-10             1.6686           1.69048               1.69048
# 223198  Marseille            Evian TG  2011-09-21             1.4068           1.67354               1.67354
# 224926  Marseille            Dortmund  2011-09-28             2.7942           1.53768               1.53768
# 225949  Marseille               Brest  2011-10-02             1.3700           1.77074               1.77074
# 229144  Marseille             Arsenal  2011-10-19             2.2800           1.75340               1.75340
# 229709  Marseille          AC Ajaccio  2011-10-22             1.2750           1.90392               1.90392
# 233313  Marseille                Nice  2011-11-06             1.4361           1.82520               1.82520
# 236035  Marseille  Olympiakos Piraeus  2011-11-23             1.6389           1.83106               1.83106
# 236830  Marseille            Paris SG  2011-11-27             2.2600           1.60000               1.60000
# 238710  Marseille            Bordeaux  2011-12-10             1.7132           1.77800               1.77800
# 239648  Marseille             Lorient  2011-12-17             1.5044           1.66464               1.66464
# 242132  Marseille               Lille  2012-01-15             1.9618           1.71052               1.71052
# 243110  Marseille            Le Havre  2012-01-22             1.2959           1.81566               1.81566
# 244640  Marseille                Nice  2012-02-01             1.3650           1.74706               1.74706
# 245191  Marseille                Lyon  2012-02-05             2.0621           1.56806               1.56806
# 246620  Marseille      Bourg Peronnas  2012-02-15             1.1888           1.63784               1.63784
# 247074  Marseille        Valenciennes  2012-02-18             1.5829           1.57472               1.57472
# 247818  Marseille               Inter  2012-02-22             1.9388           1.49894               1.49894
# 249531  Marseille            Toulouse  2012-03-03             1.7193           1.62752               1.62752
# 252504  Marseille               Dijon  2012-03-17             1.4239           1.69838               1.69838
# 255258  Marseille       Bayern Munich  2012-03-28             4.6862           1.57074               1.57074
# 258525  Marseille         Montpellier  2012-04-11             2.9000           2.27022               2.27022
# 260118  Marseille                Caen  2012-04-18             1.5030           2.53364               2.53364
# 263460  Marseille               Nancy  2012-05-02             1.5981           2.44648               2.44648
# 265975  Marseille             Auxerre  2012-05-13             1.9411           2.42224               2.42224
# 272223  Marseille             Benfica  2012-07-13             3.1358           2.52568               2.52568
# 275960  Marseille       Eskisehirspor  2012-08-09             1.3719           2.21560               2.21560
# 278314  Marseille             Sochaux  2012-08-19             1.4338           1.90998               1.90998
# 280844  Marseille    Sheriff Tiraspol  2012-08-30             1.2154           1.89614               1.89614
# 281836  Marseille              Rennes  2012-09-02             1.9732           1.81960               1.81960
# 286587  Marseille            Evian TG  2012-09-23             1.3985           1.82602               1.82602
# 289471  Marseille        AEL Limassol  2012-10-04             1.4007           1.47856               1.47856
# 290494  Marseille            Paris SG  2012-10-07             2.9904           1.48432               1.48432
# 297586  Marseille  B. Monchengladbach  2012-11-08             1.8829           1.79564               1.79564
# 298438  Marseille                Nice  2012-11-11             1.5004           1.92914               1.92914
# 300492  Marseille          Fenerbahce  2012-11-22             1.9443           1.83458               1.83458
# 301263  Marseille               Lille  2012-11-25             2.2000           1.94374               1.94374
# 301770  Marseille                Lyon  2012-11-28             2.0546           2.10360               2.10360
# 303479  Marseille             Lorient  2012-12-09             1.6007           1.91644               1.91644
# 305037  Marseille          St Etienne  2012-12-23             1.8261           1.86000               1.86000
# 305981  Marseille            Guingamp  2013-01-06             1.4200           1.92514               1.92514
# 307334  Marseille         Montpellier  2013-01-19             1.8696           1.82028               1.82028
# 309644  Marseille               Nancy  2013-02-03             1.4068           1.75420               1.75420
# 311730  Marseille        Valenciennes  2013-02-16             1.5657           1.62464               1.62464
# 314704  Marseille              Troyes  2013-03-03             1.4463           1.61764               1.61764
# 317177  Marseille          AC Ajaccio  2013-03-15             1.4581           1.54168               1.54168
# 321521  Marseille            Bordeaux  2013-04-05             1.9250           1.54930               1.54930
# 325881  Marseille               Brest  2013-04-20             1.3526           1.56038               1.56038
# 329729  Marseille              Bastia  2013-05-04             1.5921           1.54954               1.54954
# 331564  Marseille            Toulouse  2013-05-11             1.7914           1.55482               1.55482
# 335064  Marseille               Reims  2013-05-26             1.4939           1.62384               1.62384
# 340129  Marseille            FC Porto  2013-07-13             3.4767           1.63100               1.63100
# 345950  Marseille            Evian TG  2013-08-17             1.4586           1.94134               1.94134
# 349948  Marseille              Monaco  2013-09-01             2.9375           1.96254               1.96254
# 353757  Marseille             Arsenal  2013-09-18             3.4067           2.23162               2.23162
# 355521  Marseille          St Etienne  2013-09-24             2.0900           2.55468               2.55468
# 358936  Marseille            Paris SG  2013-10-06             4.1152           2.67390               2.67390
# 362541  Marseille              Napoli  2013-10-22             2.6930           2.80160               2.80160
# 363208  Marseille               Reims  2013-10-26             1.5859           3.04848               3.04848
# 367131  Marseille             Sochaux  2013-11-10             1.5110           2.77816               2.77816
# 370172  Marseille         Montpellier  2013-11-29             1.8459           2.39902               2.39902
# 371514  Marseille              Nantes  2013-12-06             1.8229           2.35020               2.35020
# 372494  Marseille            Dortmund  2013-12-11             7.5493           1.89174               1.89174
# 373426  Marseille            Toulouse  2013-12-18             1.8407           2.86300               2.86300
# 373954  Marseille            Bordeaux  2013-12-22             1.9659           2.91396               2.91396
# 374988  Marseille               Reims  2014-01-05             1.5552           3.00494               3.00494
# 377010  Marseille                Nice  2014-01-21             1.4763           2.94680               2.94680
# 378268  Marseille        Valenciennes  2014-01-29             1.5912           2.87748               2.87748
# 379006  Marseille            Toulouse  2014-02-02             1.7829           1.68586               1.68586
# 379974  Marseille              Bastia  2014-02-08             1.5659           1.67430               1.67430
# 382612  Marseille             Lorient  2014-02-22             1.7141           1.59430               1.59430
# 385180  Marseille                Nice  2014-03-07             1.5300           1.62608               1.62608
# 389023  Marseille              Rennes  2014-03-22             1.6768           1.63682               1.63682
# 392213  Marseille          AC Ajaccio  2014-04-04             1.3262           1.65394               1.65394
# 396626  Marseille               Lille  2014-04-20             2.2121           1.56260               1.56260
# 400112  Marseille                Lyon  2014-05-04             2.0275           1.69184               1.69184
# 402693  Marseille            Guingamp  2014-05-17             1.4178           1.75452               1.75452
# 409978  Marseille             Benfica  2014-07-23             2.4196           1.73208               1.73208
# 410787  Marseille           Willem II  2014-07-27             1.3700           1.88064               1.88064
# 411708  Marseille              Chievo  2014-08-02             1.4644           1.88940               1.88940
# 415179  Marseille         Montpellier  2014-08-17             1.6022           1.73986               1.73986
# 417885  Marseille                Nice  2014-08-29             1.5130           1.65480               1.65480
# 423286  Marseille              Rennes  2014-09-20             1.5664           1.67384               1.67384
# 425860  Marseille          St Etienne  2014-09-28             1.8238           1.50320               1.50320
# 430815  Marseille            Toulouse  2014-10-19             1.6082           1.59396               1.59396
# 434609  Marseille                Lens  2014-11-02             1.2517           1.62272               1.62272
# 438908  Marseille            Bordeaux  2014-11-23             1.7036           1.55262               1.55262
# 439551  Marseille              Nantes  2014-11-28             1.5618           1.59074               1.59074
# 441619  Marseille                Metz  2014-12-07             1.3454           1.58982               1.58982
# 443747  Marseille               Lille  2014-12-21             1.6439           1.49414               1.49414
# 446406  Marseille            Guingamp  2015-01-18             1.4307           1.50128               1.50128
# 448256  Marseille            Evian TG  2015-01-31             1.3407           1.53708               1.53708
# 450425  Marseille               Reims  2015-02-13             1.3297           1.46450               1.46450
# 453120  Marseille                Caen  2015-02-27             1.4329           1.41808               1.41808
# 457479  Marseille                Lyon  2015-03-15             2.1986           1.43558               1.43558
# 462416  Marseille            Paris SG  2015-04-05             3.6117           1.54652               1.54652
# 467114  Marseille             Lorient  2015-04-24             1.3648           1.98272               1.98272
# 471600  Marseille              Monaco  2015-05-10             2.3228           1.98754               1.98754
# 474416  Marseille              Bastia  2015-05-23             1.2021           2.18616               2.18616

# %%
X = Closing_Odds.loc[:, ["avg_home_win_est", "avg_away_win_est"]]
y = Closing_Odds['condition']
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42, stratify=y
)

# Let's take a classic Decision Tree for now. Explainable, handles classs imbalance and intuitive 
model = DecisionTreeClassifier(random_state = 77, class_weight='balanced', max_depth=4)

# Train the model
model.fit(X_train, y_train)

# Predict probabilities for AUC-ROC
y_pred_proba = model.predict_proba(X_test)[:, 1]

# Evaluate
fpr, tpr, threshold = metrics.roc_curve(y_test, y_pred_proba)
roc_auc = metrics.auc(fpr, tpr)
auc = roc_auc_score(y_test, y_pred_proba)
print(f'AUC-ROC: {auc:.4f}')

pl.title('Receiver Operating Characteristic')
pl.plot(fpr, tpr, 'r', label = 'AUC = %0.2f' % roc_auc)
pl.legend(loc = 'lower right')
pl.plot([0, 1], [0, 1],color = 'black',linestyle='--')
pl.xlim([0, 1])
pl.ylim([0, 1])
pl.ylabel('True Positive Rate')
pl.xlabel('False Positive Rate')
pl.show()

# Also, print a classification report
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
print(model.feature_importances_)
# Out:
# AUC-ROC: 0.5123
#               precision    recall  f1-score   support
#
#        False       0.92      0.08      0.14    126902
#         True       0.12      0.95      0.21     16930
#
#     accuracy                           0.18    143832
#    macro avg       0.52      0.51      0.18    143832
# weighted avg       0.82      0.18      0.15    143832
#
# [0.66544653 0.33455347]

# %% [markdown]
# ### #6: Recent form (Goal Average)

# %% [markdown]
# If winrate aren't cutting it, maybe goal average will. To test this new hypothesis, we'll add a feature that contains the difference in goals scored-conceded for both teams, to assess who's going into this new game better prepared.
#
# The idea is similar to the previous one : if a team scores more and concedes less, they are probably favorites, and therefore it has an impact on the odds that will be distributed.

# %%
def home_team_last_5_ga(df):

    last_5_ga = []

    # Dictionary to track the last 5 games of each home team
    team_history = {}

    for _, row in df.iterrows():
        home_team = row['home_team']
        result = row['home_score']-row['away_score']

        # Initialize team history if not present
        if home_team not in team_history:
            team_history[home_team] = []

        # Calculate win rate for the last 5 games
        recent_results = team_history[home_team]
        if len(recent_results) > 0:
            ga = sum(recent_results)

            
        else:
            ga = 0
        last_5_ga.append(ga)

        # Update the team's history with the current game result
        if len(recent_results) == 5:
            recent_results.pop(0)  # Remove the oldest result
        recent_results.append(result)

    return pd.Series(last_5_ga, name='home_last_5_ga')

Last_5_H_GA = home_team_last_5_ga(Closing_Odds)

# %%
def away_team_last_5_ga(df):

    last_5_ga = []

    # Dictionary to track the last 5 games of each home team
    team_history = {}

    for _, row in df.iterrows():
        away_team = row['away_team']
        result = row['away_score']-row['home_score']

        # Initialize team history if not present
        if away_team not in team_history:
            team_history[away_team] = []

        # Calculate win rate for the last 5 games
        recent_results = team_history[away_team]
        if len(recent_results) > 0:
            ga = sum(recent_results)

            
        else:
            ga = 0
        last_5_ga.append(ga)

        # Update the team's history with the current game result
        if len(recent_results) == 5:
            recent_results.pop(0)  # Remove the oldest result
        recent_results.append(result)

    return pd.Series(last_5_ga, name='away_last_5_ga')

Last_5_A_GA = away_team_last_5_ga(Closing_Odds)

# %%
Closing_Odds['Home_GA'] = Last_5_H_GA
Closing_Odds['Away_GA'] = Last_5_A_GA

# %%
X = list(sorted(Closing_Odds['Home_GA'].unique()))
Y = Closing_Odds.groupby('Home_GA')['condition'].describe()["count"]
Y2 = Closing_Odds[Closing_Odds['condition']==True].groupby('Home_GA')['condition'].describe()["count"]

ratios = (Y2 / Y) * 100

fig, axes = pl.subplots(1, 2, figsize=(12, 6))

axes[0].bar(x=X, height=Y, width=.7, align='center')
axes[0].set_title("N° games per difference in GA for Home team")


axes[1].bar(x=X, height=ratios, width=.7, color='grey', align='center')
axes[1].set_title("% of 'good' games per GA difference")


pl.tight_layout()
pl.show()

# %%
X = list(sorted(Closing_Odds['Away_GA'].unique()))
Y = Closing_Odds.groupby('Away_GA')['condition'].describe()["count"]
Y2 = Closing_Odds[Closing_Odds['condition']==True].groupby('Away_GA')['condition'].describe()["count"]

ratios = (Y2 / Y) * 100

fig, axes = pl.subplots(1, 2, figsize=(12, 6))

axes[0].bar(x=X, height=Y, width=.7, align='center')
axes[0].set_title("N° games per difference in GA for Away team")


axes[1].bar(x=X, height=ratios, width=.7, color='grey', align='center')
axes[1].set_title("% of 'good' games per GA difference")


pl.tight_layout()
pl.show()

# %% [markdown]
# This time, our metrics lead us to the expected conclusion. However, the fact that games with a |GA_difference| higher than 10 are so rare that this will never hold any weight in our model. It would've been great though.
